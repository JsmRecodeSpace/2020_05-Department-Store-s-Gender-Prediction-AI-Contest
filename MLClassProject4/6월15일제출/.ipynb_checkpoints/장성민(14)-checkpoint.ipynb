# %% [markdown]
# ## Csv. 장성민(14)
#
#     - 지금까지 가장 잘 나온 성능인 DAE모델과 DNN 모델의 앙상블을 해보았습니다.
#     - 0.7945 + 0.7800 -> 기하평균

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
from matplotlib import font_manager, rc
# %matplotlib inline

import platform
your_os = platform.system()
if your_os == 'Linux':
    rc('font', family='NanumGothic')
elif your_os == 'Windows':
    ttf = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=ttf).get_name()
    rc('font', family=font_name)
elif your_os == 'Darwin':
    rc('font', family='AppleGothic')
rc('axes', unicode_minus=False)

# %%
# submission간 상관관계보기

ae_sub7945= pd.read_csv('장성민(5).csv', encoding='cp949')
dnn_sub7800 = pd.read_csv('장성민(6).csv',encoding='cp949')

# gender 이름 바꾸기전

submissions = [ae_sub7945,dnn_sub7800]

print(len(submissions))

names= ['ae_sub7945','dnn_sub7800']

# 각 submission별 gender 칼럼명 변경

for i in range(len(submissions)):

    submissions[i].rename(columns={'gender':f'{names[i]}'}, inplace=True)
# Out:
# 2

# %%
        n=1

        for submission in submissions:

            print(n); n +=1
    
    display(submission)
# Out:
# 1
#       cust_id  ae_sub7945
# 0        3500    0.624349
# 1        3501    0.222895
# 2        3502    0.228073
# 3        3503    0.227053
# 4        3504    0.457989
# ...       ...         ...
# 2477     5977    0.526266
# 2478     5978    0.445524
# 2479     5979    0.608206
# 2480     5980    0.375190
# 2481     5981    0.545628
#
# [2482 rows x 2 columns]
# 2
#       cust_id  dnn_sub7800
# 0        3500     0.570821
# 1        3501     0.359843
# 2        3502     0.377952
# 3        3503     0.388892
# 4        3504     0.514798
# ...       ...          ...
# 2477     5977     0.473310
# 2478     5978     0.422023
# 2479     5979     0.526943
# 2480     5980     0.496387
# 2481     5981     0.552926
#
# [2482 rows x 2 columns]

# %%
# 데이터 합치기

data = pd.DataFrame({'cust_id': range(3500,5982)})
for sub in submissions :
    data = pd.merge(data, sub, how='left', on='cust_id')
display(data)
data.info()
# Out:
#       cust_id  ae_sub7945  dnn_sub7800
# 0        3500    0.624349     0.570821
# 1        3501    0.222895     0.359843
# 2        3502    0.228073     0.377952
# 3        3503    0.227053     0.388892
# 4        3504    0.457989     0.514798
# ...       ...         ...          ...
# 2477     5977    0.526266     0.473310
# 2478     5978    0.445524     0.422023
# 2479     5979    0.608206     0.526943
# 2480     5980    0.375190     0.496387
# 2481     5981    0.545628     0.552926
#
# [2482 rows x 3 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2482 entries, 0 to 2481
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cust_id      2482 non-null   int64
#  1   ae_sub7945   2482 non-null   float64
#  2   dnn_sub7800  2482 non-null   float64
# dtypes: float64(2), int64(1)
# memory usage: 77.6 KB

# %%
data = data.drop('cust_id', axis=1); data
# Out:
#       ae_sub7945  dnn_sub7800
# 0       0.624349     0.570821
# 1       0.222895     0.359843
# 2       0.228073     0.377952
# 3       0.227053     0.388892
# 4       0.457989     0.514798
# ...          ...          ...
# 2477    0.526266     0.473310
# 2478    0.445524     0.422023
# 2479    0.608206     0.526943
# 2480    0.375190     0.496387
# 2481    0.545628     0.552926
#
# [2482 rows x 2 columns]

# %%
# 서브미션간 상관관계 히트맵

plt.figure(figsize=(20,11))
sns.heatmap(data.corr(), annot=True, cmap='RdYlBu_r', linewidths=0.2)
plt.show()

# %%
# 기하평균
pred = (ae_sub7945['ae_sub7945'] * dnn_sub7800['dnn_sub7800']) ** (1/2)
jsm14 = pd.DataFrame({'cust_id':range(3500, 5982), 'gender':pred})
jsm14.to_csv('장성민(14).csv', encoding='cp949', index=False)

# %%
jsm14.isnull().any()
# Out:
# cust_id    False
# gender     False
# dtype: bool
