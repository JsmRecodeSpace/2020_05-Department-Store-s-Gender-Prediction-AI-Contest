# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
from matplotlib import font_manager, rc
# %matplotlib inline

import platform
your_os = platform.system()
if your_os == 'Linux':
    rc('font', family='NanumGothic')
elif your_os == 'Windows':
    ttf = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=ttf).get_name()
    rc('font', family=font_name)
elif your_os == 'Darwin':
    rc('font', family='AppleGothic')
rc('axes', unicode_minus=False)

# %%
## Baseline: 0.80985

# 그룹과제 1등, 2등, 3등
score7981 = pd.read_csv('박혜지(7981).csv', encoding='cp949') # 14
score7977 = pd.read_csv('서진영(7977).csv', encoding='cp949') # 18
score7988 = pd.read_csv('홍재성(7988).csv', encoding='cp949') # 19

# 개인과제2 1등, 2등, 3등
w2v_7932 = pd.read_csv('김세홍(7932).csv', encoding='cp949')
w2v_7913 = pd.read_csv('권오현(7913).csv', encoding='cp949')
w2v_7883 = pd.read_csv('오주영(7883).csv', encoding='cp949')

# NN과제 1등, 2등, 3등
esem8055 = pd.read_csv('yj8055.csv', encoding='cp949')
esem8040 = pd.read_csv('hong8040.csv', encoding='cp949')
esem8031 = pd.read_csv('jin8031.csv', encoding='cp949')

# NN만점과제
Dnn7982 = pd.read_csv('Dnn7982.csv', encoding='cp949')
Dae7971 = pd.read_csv('DAE7971.csv', encoding='cp949')
Cnn7974 = pd.read_csv('Cnn17974.csv', encoding='cp949')

# 우리과제
ml_7880 = pd.read_csv('18logreg2(7880).csv', encoding='cp949')
ml_7868 = pd.read_csv('20logreg3(7868).csv', encoding='cp949')
ml_7830 = pd.read_csv('jun7830.csv', encoding='cp949')
w2v7789 = pd.read_csv('w2v송민규1.csv', encoding='cp949')
w2v7933 = pd.read_csv('w2v7933.csv', encoding='cp949')
Dnn_w2v_7800 = pd.read_csv('Dnn_w2v7800.csv', encoding='cp949')
Dae_us_7971 = pd.read_csv('DAE_us_7971.csv', encoding='cp949')

# %%
# gender 이름 바꾸기전

submissions = [
    
# 그룹과제 1등, 2등, 3등
    score7981, score7977, score7988,
    
# 개인과제2 1등, 2등, 3등
    w2v_7932, w2v_7913, w2v_7883,

# NN과제 1등, 2등, 3등
    esem8055, esem8040, esem8031,

# NN만점과제
    Dnn7982, Dae7971, Cnn7974,

# 우리과제
    ml_7880, ml_7868, ml_7830, w2v7789, w2v7933, Dnn_w2v_7800, Dae_us_7971,
    
    
              ]
print(len(submissions))

names= [
    
# 그룹과제 1등, 2등, 3등
    'score7981', 'score7977', 'score7988',
    
# 개인과제2 1등, 2등, 3등
    'w2v_7932' ,'w2v_7913' ,'w2v_7883',

# NN과제 1등, 2등, 3등
    'esem8055', 'esem8040', 'esem8031',

# NN만점과제
    'Dnn7982', 'Dae7971', 'Cnn7974',

# 우리과제
    'ml_7880', 'ml_7868', 'ml_7830', 'w2v7789', 'w2v7933', 'Dnn_w2v_7800', 'Dae_us_7971',

       ]
# Out:
# 19

# %%
# 각 submission별 gender 칼럼명 변경

for i in range(len(submissions)):
    

    submissions[i].rename(columns={'gender':f'{names[i]}'}, inplace=True)

# %%
        n=1

        for submission in submissions:

            print(n); n +=1
    
    display(submission)
# Out:
# 1
#       cust_id  score7981
# 0        3500   0.703970
# 1        3501   0.261014
# 2        3502   0.223002
# 3        3503   0.298456
# 4        3504   0.477007
# ...       ...        ...
# 2477     5977   0.476866
# 2478     5978   0.397060
# 2479     5979   0.783580
# 2480     5980   0.425649
# 2481     5981   0.544029
#
# [2482 rows x 2 columns]
# 2
#       cust_id  score7977
# 0        3500   0.838103
# 1        3501   0.148406
# 2        3502   0.126179
# 3        3503   0.195933
# 4        3504   0.401645
# ...       ...        ...
# 2477     5977   0.585520
# 2478     5978   0.361859
# 2479     5979   0.742040
# 2480     5980   0.381033
# 2481     5981   0.528198
#
# [2482 rows x 2 columns]
# 3
#       cust_id  score7988
# 0        3500   0.743568
# 1        3501   0.361648
# 2        3502   0.198195
# 3        3503   0.207855
# 4        3504   0.396858
# ...       ...        ...
# 2477     5977   0.421573
# 2478     5978   0.404951
# 2479     5979   0.763675
# 2480     5980   0.578213
# 2481     5981   0.632406
#
# [2482 rows x 2 columns]
# 4
#       cust_id  w2v_7932
# 0        3500  0.811783
# 1        3501  0.252860
# 2        3502  0.306382
# 3        3503  0.332137
# 4        3504  0.316166
# ...       ...       ...
# 2477     5977  0.419412
# 2478     5978  0.333345
# 2479     5979  0.891557
# 2480     5980  0.378279
# 2481     5981  0.678864
#
# [2482 rows x 2 columns]
# 5
#       cust_id  w2v_7913
# 0        3500  0.620901
# 1        3501  0.236004
# 2        3502  0.191783
# 3        3503  0.301800
# 4        3504  0.354402
# ...       ...       ...
# 2477     5977  0.583794
# 2478     5978  0.249692
# 2479     5979  0.495129
# 2480     5980  0.419697
# 2481     5981  0.562409
#
# [2482 rows x 2 columns]
# 6
#       cust_id  w2v_7883
# 0        3500  0.674242
# 1        3501  0.093854
# 2        3502  0.121679
# 3        3503  0.266706
# 4        3504  0.366850
# ...       ...       ...
# 2477     5977  0.370376
# 2478     5978  0.171592
# 2479     5979  0.392825
# 2480     5980  0.312310
# 2481     5981  0.610050
#
# [2482 rows x 2 columns]
# 7
#       cust_id  esem8055
# 0        3500  0.783190
# 1        3501  0.249035
# 2        3502  0.206842
# 3        3503  0.242358
# 4        3504  0.341752
# ...       ...       ...
# 2477     5977  0.616425
# 2478     5978  0.344216
# 2479     5979  0.785444
# 2480     5980  0.402934
# 2481     5981  0.523529
#
# [2482 rows x 2 columns]
# 8
#       cust_id  esem8040
# 0        3500  0.705826
# 1        3501  0.267778
# 2        3502  0.205548
# 3        3503  0.279232
# 4        3504  0.461922
# ...       ...       ...
# 2477     5977  0.477228
# 2478     5978  0.423558
# 2479     5979  0.734557
# 2480     5980  0.424679
# 2481     5981  0.594811
#
# [2482 rows x 2 columns]
# 9
#       cust_id  esem8031
# 0        3500  0.698142
# 1        3501  0.198966
# 2        3502  0.213388
# 3        3503  0.322556
# 4        3504  0.423460
# ...       ...       ...
# 2477     5977  0.489347
# 2478     5978  0.385089
# 2479     5979  0.706593
# 2480     5980  0.379820
# 2481     5981  0.550135
#
# [2482 rows x 2 columns]
# 10
#       cust_id   Dnn7982
# 0        3500  0.718546
# 1        3501  0.246766
# 2        3502  0.178112
# 3        3503  0.578469
# 4        3504  0.621076
# ...       ...       ...
# 2477     5977  0.633926
# 2478     5978  0.266491
# 2479     5979  0.755670
# 2480     5980  0.398160
# 2481     5981  0.672710
#
# [2482 rows x 2 columns]
# 11
#       cust_id   Dae7971
# 0        3500  0.571990
# 1        3501  0.241759
# 2        3502  0.150302
# 3        3503  0.306411
# 4        3504  0.486499
# ...       ...       ...
# 2477     5977  0.480310
# 2478     5978  0.477930
# 2479     5979  0.591918
# 2480     5980  0.386131
# 2481     5981  0.502319
#
# [2482 rows x 2 columns]
# 12
#       cust_id   Cnn7974
# 0        3500  0.611167
# 1        3501  0.319969
# 2        3502  0.423284
# 3        3503  0.354171
# 4        3504  0.473791
# ...       ...       ...
# 2477     5977  0.424815
# 2478     5978  0.402117
# 2479     5979  0.522821
# 2480     5980  0.410776
# 2481     5981  0.528627
#
# [2482 rows x 2 columns]
# 13
#       cust_id   ml_7880
# 0        3500  0.793732
# 1        3501  0.214731
# 2        3502  0.132957
# 3        3503  0.158616
# 4        3504  0.311544
# ...       ...       ...
# 2477     5977  0.455184
# 2478     5978  0.288089
# 2479     5979  0.774292
# 2480     5980  0.453790
# 2481     5981  0.527846
#
# [2482 rows x 2 columns]
# 14
#       cust_id   ml_7868
# 0        3500  0.811754
# 1        3501  0.204271
# 2        3502  0.125935
# 3        3503  0.183855
# 4        3504  0.324266
# ...       ...       ...
# 2477     5977  0.653992
# 2478     5978  0.300663
# 2479     5979  0.761532
# 2480     5980  0.372018
# 2481     5981  0.493476
#
# [2482 rows x 2 columns]
# 15
#       cust_id   ml_7830
# 0        3500  0.761307
# 1        3501  0.193536
# 2        3502  0.156237
# 3        3503  0.336666
# 4        3504  0.405982
# ...       ...       ...
# 2477     5977  0.494179
# 2478     5978  0.330115
# 2479     5979  0.763123
# 2480     5980  0.303355
# 2481     5981  0.535597
#
# [2482 rows x 2 columns]
# 16
#       cust_id   w2v7789
# 0        3500  0.740952
# 1        3501  0.168776
# 2        3502  0.227124
# 3        3503  0.251779
# 4        3504  0.296974
# ...       ...       ...
# 2477     5977  0.320474
# 2478     5978  0.274367
# 2479     5979  0.493818
# 2480     5980  0.434032
# 2481     5981  0.624412
#
# [2482 rows x 2 columns]
# 17
#       cust_id   w2v7933
# 0        3500  0.568282
# 1        3501  0.253667
# 2        3502  0.231261
# 3        3503  0.202614
# 4        3504  0.474797
# ...       ...       ...
# 2477     5977  0.434098
# 2478     5978  0.347144
# 2479     5979  0.706995
# 2480     5980  0.520377
# 2481     5981  0.651189
#
# [2482 rows x 2 columns]
# 18
#       cust_id  Dnn_w2v_7800
# 0        3500      0.570821
# 1        3501      0.359843
# 2        3502      0.377952
# 3        3503      0.388892
# 4        3504      0.514798
# ...       ...           ...
# 2477     5977      0.473310
# 2478     5978      0.422023
# 2479     5979      0.526943
# 2480     5980      0.496387
# 2481     5981      0.552926
#
# [2482 rows x 2 columns]
# 19
#       cust_id  Dae_us_7971
# 0        3500     0.605614
# 1        3501     0.270827
# 2        3502     0.280531
# 3        3503     0.283697
# 4        3504     0.477872
# ...       ...          ...
# 2477     5977     0.507732
# 2478     5978     0.437299
# 2479     5979     0.579764
# 2480     5980     0.417609
# 2481     5981     0.548182
#
# [2482 rows x 2 columns]

# %%
# 데이터 합치기

data = pd.DataFrame({'cust_id': range(3500,5982)})
for sub in submissions :
    data = pd.merge(data, sub, how='left', on='cust_id')
display(data)
data.info()
# Out:
#       cust_id  score7981  score7977  score7988  w2v_7932  w2v_7913  w2v_7883  \
# 0        3500   0.703970   0.838103   0.743568  0.811783  0.620901  0.674242
# 1        3501   0.261014   0.148406   0.361648  0.252860  0.236004  0.093854
# 2        3502   0.223002   0.126179   0.198195  0.306382  0.191783  0.121679
# 3        3503   0.298456   0.195933   0.207855  0.332137  0.301800  0.266706
# 4        3504   0.477007   0.401645   0.396858  0.316166  0.354402  0.366850
# ...       ...        ...        ...        ...       ...       ...       ...
# 2477     5977   0.476866   0.585520   0.421573  0.419412  0.583794  0.370376
# 2478     5978   0.397060   0.361859   0.404951  0.333345  0.249692  0.171592
# 2479     5979   0.783580   0.742040   0.763675  0.891557  0.495129  0.392825
# 2480     5980   0.425649   0.381033   0.578213  0.378279  0.419697  0.312310
# 2481     5981   0.544029   0.528198   0.632406  0.678864  0.562409  0.610050
#
#       esem8055  esem8040  esem8031   Dnn7982   Dae7971   Cnn7974   ml_7880  \
# 0     0.783190  0.705826  0.698142  0.718546  0.571990  0.611167  0.793732
# 1     0.249035  0.267778  0.198966  0.246766  0.241759  0.319969  0.214731
# 2     0.206842  0.205548  0.213388  0.178112  0.150302  0.423284  0.132957
# 3     0.242358  0.279232  0.322556  0.578469  0.306411  0.354171  0.158616
# 4     0.341752  0.461922  0.423460  0.621076  0.486499  0.473791  0.311544
# ...        ...       ...       ...       ...       ...       ...       ...
# 2477  0.616425  0.477228  0.489347  0.633926  0.480310  0.424815  0.455184
# 2478  0.344216  0.423558  0.385089  0.266491  0.477930  0.402117  0.288089
# 2479  0.785444  0.734557  0.706593  0.755670  0.591918  0.522821  0.774292
# 2480  0.402934  0.424679  0.379820  0.398160  0.386131  0.410776  0.453790
# 2481  0.523529  0.594811  0.550135  0.672710  0.502319  0.528627  0.527846
#
#        ml_7868   ml_7830   w2v7789   w2v7933  Dnn_w2v_7800  Dae_us_7971
# 0     0.811754  0.761307  0.740952  0.568282      0.570821     0.605614
# 1     0.204271  0.193536  0.168776  0.253667      0.359843     0.270827
# 2     0.125935  0.156237  0.227124  0.231261      0.377952     0.280531
# 3     0.183855  0.336666  0.251779  0.202614      0.388892     0.283697
# 4     0.324266  0.405982  0.296974  0.474797      0.514798     0.477872
# ...        ...       ...       ...       ...           ...          ...
# 2477  0.653992  0.494179  0.320474  0.434098      0.473310     0.507732
# 2478  0.300663  0.330115  0.274367  0.347144      0.422023     0.437299
# 2479  0.761532  0.763123  0.493818  0.706995      0.526943     0.579764
# 2480  0.372018  0.303355  0.434032  0.520377      0.496387     0.417609
# 2481  0.493476  0.535597  0.624412  0.651189      0.552926     0.548182
#
# [2482 rows x 20 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2482 entries, 0 to 2481
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cust_id       2482 non-null   int64
#  1   score7981     2482 non-null   float64
#  2   score7977     2482 non-null   float64
#  3   score7988     2482 non-null   float64
#  4   w2v_7932      2482 non-null   float64
#  5   w2v_7913      2482 non-null   float64
#  6   w2v_7883      2482 non-null   float64
#  7   esem8055      2482 non-null   float64
#  8   esem8040      2482 non-null   float64
#  9   esem8031      2482 non-null   float64
#  10  Dnn7982       2482 non-null   float64
#  11  Dae7971       2482 non-null   float64
#  12  Cnn7974       2482 non-null   float64
#  13  ml_7880       2482 non-null   float64
#  14  ml_7868       2482 non-null   float64
#  15  ml_7830       2482 non-null   float64
#  16  w2v7789       2482 non-null   float64
#  17  w2v7933       2482 non-null   float64
#  18  Dnn_w2v_7800  2482 non-null   float64
#  19  Dae_us_7971   2482 non-null   float64
# dtypes: float64(19), int64(1)
# memory usage: 407.2 KB

# %%
data = data.drop('cust_id', axis=1); data
# Out:
#       score7981  score7977  score7988  w2v_7932  w2v_7913  w2v_7883  esem8055  \
# 0      0.703970   0.838103   0.743568  0.811783  0.620901  0.674242  0.783190
# 1      0.261014   0.148406   0.361648  0.252860  0.236004  0.093854  0.249035
# 2      0.223002   0.126179   0.198195  0.306382  0.191783  0.121679  0.206842
# 3      0.298456   0.195933   0.207855  0.332137  0.301800  0.266706  0.242358
# 4      0.477007   0.401645   0.396858  0.316166  0.354402  0.366850  0.341752
# ...         ...        ...        ...       ...       ...       ...       ...
# 2477   0.476866   0.585520   0.421573  0.419412  0.583794  0.370376  0.616425
# 2478   0.397060   0.361859   0.404951  0.333345  0.249692  0.171592  0.344216
# 2479   0.783580   0.742040   0.763675  0.891557  0.495129  0.392825  0.785444
# 2480   0.425649   0.381033   0.578213  0.378279  0.419697  0.312310  0.402934
# 2481   0.544029   0.528198   0.632406  0.678864  0.562409  0.610050  0.523529
#
#       esem8040  esem8031   Dnn7982   Dae7971   Cnn7974   ml_7880   ml_7868  \
# 0     0.705826  0.698142  0.718546  0.571990  0.611167  0.793732  0.811754
# 1     0.267778  0.198966  0.246766  0.241759  0.319969  0.214731  0.204271
# 2     0.205548  0.213388  0.178112  0.150302  0.423284  0.132957  0.125935
# 3     0.279232  0.322556  0.578469  0.306411  0.354171  0.158616  0.183855
# 4     0.461922  0.423460  0.621076  0.486499  0.473791  0.311544  0.324266
# ...        ...       ...       ...       ...       ...       ...       ...
# 2477  0.477228  0.489347  0.633926  0.480310  0.424815  0.455184  0.653992
# 2478  0.423558  0.385089  0.266491  0.477930  0.402117  0.288089  0.300663
# 2479  0.734557  0.706593  0.755670  0.591918  0.522821  0.774292  0.761532
# 2480  0.424679  0.379820  0.398160  0.386131  0.410776  0.453790  0.372018
# 2481  0.594811  0.550135  0.672710  0.502319  0.528627  0.527846  0.493476
#
#        ml_7830   w2v7789   w2v7933  Dnn_w2v_7800  Dae_us_7971
# 0     0.761307  0.740952  0.568282      0.570821     0.605614
# 1     0.193536  0.168776  0.253667      0.359843     0.270827
# 2     0.156237  0.227124  0.231261      0.377952     0.280531
# 3     0.336666  0.251779  0.202614      0.388892     0.283697
# 4     0.405982  0.296974  0.474797      0.514798     0.477872
# ...        ...       ...       ...           ...          ...
# 2477  0.494179  0.320474  0.434098      0.473310     0.507732
# 2478  0.330115  0.274367  0.347144      0.422023     0.437299
# 2479  0.763123  0.493818  0.706995      0.526943     0.579764
# 2480  0.303355  0.434032  0.520377      0.496387     0.417609
# 2481  0.535597  0.624412  0.651189      0.552926     0.548182
#
# [2482 rows x 19 columns]

# %%
# 서브미션간 상관관계 히트맵

plt.figure(figsize=(20,11))
sns.heatmap(data.corr(), annot=True, cmap='RdYlBu_r', linewidths=0.2)
plt.show()

# %% [raw]
# baseline 기하평균: 0.80887

# %%
pred = (esem8055['esem8055'] * esem8040['esem8040'] * esem8031['esem8031'] * Dnn7982['Dnn7982'] * Dae7971['Dae7971'] * Cnnv1d['Cnnv1d']) ** (1/6)

sub_esemble_NN_gmean = pd.DataFrame({'cust_id':range(3500, 5982), 'gender': pred})

sub_esemble_NN_gmean.to_csv('sub_esemble_NN_gmean.csv', encoding='cp949', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-1b01e0b0eb3e> in <module>
# ----> 1 pred = (esem8055['esem8055'] * esem8040['esem8040'] * esem8031['esem8031'] * Dnn7982['Dnn7982'] * Dae7971['Dae7971'] * Cnnv1d['Cnnv1d']) ** (1/6)
#       2
#       3 sub_esemble_NN_gmean = pd.DataFrame({'cust_id':range(3500, 5982), 'gender': pred})
#       4
#       5 sub_esemble_NN_gmean.to_csv('sub_esemble_NN_gmean.csv', encoding='cp949', index=False)
#
# NameError: name 'Cnnv1d' is not defined

# %%
submission_list = [score7988, w2v_7932, Dae7971]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 3.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 3.5)


fname = 'score7988 + w2v7932 + DAE7971.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'score7988 + w2v7932 + DAE7971.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.725977
# 1        3501  0.298360
# 2        3502  0.241289
# 3        3503  0.293588
# 4        3504  0.414423
# ...       ...       ...
# 2477     5977  0.442728
# 2478     5978  0.415842
# 2479     5979  0.772932
# 2480     5980  0.471585
# 2481     5981  0.615479
#
# [2482 rows x 2 columns]

# %%
submission_list = [score7977, w2v_7913, Dnn7982, Cnn7974]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 3.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 3.5)


fname = 'score7977 + w2v_7913 + Dnn7982 + Cnn7974.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'score7977 + w2v_7913 + Dnn7982 + Cnn7974.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.712374
# 1        3501  0.255319
# 2        3502  0.294628
# 3        3503  0.420022
# 4        3504  0.490066
# ...       ...       ...
# 2477     5977  0.569753
# 2478     5978  0.335268
# 2479     5979  0.656253
# 2480     5980  0.403067
# 2481     5981  0.580898
#
# [2482 rows x 2 columns]

# %%
submission_list = [score7981, score7977, score7988, Dnn7982, Dae7971, Cnn7974]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 3.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 3.5)


fname = 'score7981, score7977, score7988, Dnn7982, Dae7971, Cnn7974.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'score7981, score7977, score7988, Dnn7982, Dae7971, Cnn7974.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.711247
# 1        3501  0.282313
# 2        3502  0.271366
# 3        3503  0.384524
# 4        3504  0.491016
# ...       ...       ...
# 2477     5977  0.519600
# 2478     5978  0.397063
# 2479     5979  0.709503
# 2480     5980  0.444560
# 2481     5981  0.576698
#
# [2482 rows x 2 columns]

# %%
submission_list = [esem8040, w2v_7913, Dnn7982, Dae7971, Cnn7974]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 3.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 3.5)


fname = 'esem8040, w2v_7913, Dnn7982, Dae7971, Cnn7974.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'esem8040, w2v_7913, Dnn7982, Dae7971, Cnn7974.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.651917
# 1        3501  0.267136
# 2        3502  0.282707
# 3        3503  0.407614
# 4        3504  0.498008
# ...       ...       ...
# 2477     5977  0.534090
# 2478     5978  0.389083
# 2479     5979  0.642522
# 2480     5980  0.408496
# 2481     5981  0.579926
#
# [2482 rows x 2 columns]

# %%
submission_list = [score7988, w2v_7883, Dae7971, ml_7880]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 3.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 3.5)


fname = 'score7988, w2v_7883, Dae7971, ml_7880.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'score7988, w2v_7883, Dae7971, ml_7880.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.707790
# 1        3501  0.268717
# 2        3502  0.157974
# 3        3503  0.250355
# 4        3504  0.403187
# ...       ...       ...
# 2477     5977  0.436615
# 2478     5978  0.377861
# 2479     5979  0.672032
# 2480     5980  0.459341
# 2481     5981  0.574576
#
# [2482 rows x 2 columns]

# %%
submission_list = [score8095, w2v_7932, Dae7971]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 3.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 3.5)


fname = 'score8095, w2v_7932, Dae7971.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'score8095, w2v_7932, Dae7971.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.708202
# 1        3501  0.251981
# 2        3502  0.263438
# 3        3503  0.348421
# 4        3504  0.446489
# ...       ...       ...
# 2477     5977  0.483822
# 2478     5978  0.413223
# 2479     5979  0.753226
# 2480     5980  0.388797
# 2481     5981  0.594853
#
# [2482 rows x 2 columns]

# %%
submission_list = [score8091, score7977, Dnn7982]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 3.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 3.5)


fname = 'score8091, score7977, Dnn7982.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'score8091, score7977, Dnn7982.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.765874
# 1        3501  0.249369
# 2        3502  0.195991
# 3        3503  0.436064
# 4        3504  0.505589
# ...       ...       ...
# 2477     5977  0.567940
# 2478     5978  0.360810
# 2479     5979  0.757145
# 2480     5980  0.421621
# 2481     5981  0.612565
#
# [2482 rows x 2 columns]

# %%
submission_list = [Cnn7974, esem8040, score8091]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 3.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 3.5)


fname = 'Cnn7974, esem8040, score8091.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'Cnn7974, esem8040, score8091.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.685449
# 1        3501  0.297280
# 2        3502  0.327303
# 3        3503  0.313327
# 4        3504  0.451834
# ...       ...       ...
# 2477     5977  0.449583
# 2478     5978  0.414076
# 2479     5979  0.697216
# 2480     5980  0.437644
# 2481     5981  0.582530
#
# [2482 rows x 2 columns]

# %%
submission_list = [w2v_7932, w2v_7913, w2v7894]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 3.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 3.5)


fname = 'w2v_7932, w2v_7913, w2v7894.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'w2v_7932, w2v_7913, w2v7894.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.687658
# 1        3501  0.247841
# 2        3502  0.254525
# 3        3503  0.291171
# 4        3504  0.396759
# ...       ...       ...
# 2477     5977  0.493725
# 2478     5978  0.317012
# 2479     5979  0.741198
# 2480     5980  0.449615
# 2481     5981  0.635563
#
# [2482 rows x 2 columns]
