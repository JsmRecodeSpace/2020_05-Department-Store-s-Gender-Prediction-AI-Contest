# %% [markdown]
# w2v7933, score7977, Dnn7982, Dae7971: 0.80664
# sota3: 0.806062
# baseline: 0.8092
# hong(0.45) jy(0.1) (duck_sota power mean(0.45)): 0.80897
# sota3esem3: 0.8095

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
from matplotlib import font_manager, rc
# %matplotlib inline

import platform
your_os = platform.system()
if your_os == 'Linux':
    rc('font', family='NanumGothic')
elif your_os == 'Windows':
    ttf = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=ttf).get_name()
    rc('font', family=font_name)
elif your_os == 'Darwin':
    rc('font', family='AppleGothic')
rc('axes', unicode_minus=False)

# %%
## Baseline: 0.80985

# 그룹과제 1등, 2등, 3등
score7981 = pd.read_csv('박혜지(7981).csv', encoding='cp949') # 14
score7977 = pd.read_csv('서진영(7977).csv', encoding='cp949') # 18
score7988 = pd.read_csv('홍재성(7988).csv', encoding='cp949') # 19

# 개인과제2 1등, 2등, 3등
w2v_7932 = pd.read_csv('김세홍(7932).csv', encoding='cp949')
w2v_7913 = pd.read_csv('권오현(7913).csv', encoding='cp949')
w2v_7883 = pd.read_csv('오주영(7883).csv', encoding='cp949')

# NN과제 1등, 2등, 3등
esem8055 = pd.read_csv('yj8055.csv', encoding='cp949')
esem8040 = pd.read_csv('hong8040.csv', encoding='cp949')
esem8031 = pd.read_csv('jin8031.csv', encoding='cp949')

# NN만점과제
Dnn7982 = pd.read_csv('Dnn7982.csv', encoding='cp949')
Dae7971 = pd.read_csv('DAE7971.csv', encoding='cp949')
Cnn7974 = pd.read_csv('Cnn17974.csv', encoding='cp949')

# 우리과제
ml_7880 = pd.read_csv('18logreg2(7880).csv', encoding='cp949')
ml_7868 = pd.read_csv('20logreg3(7868).csv', encoding='cp949')
ml_7830 = pd.read_csv('jun7830.csv', encoding='cp949')
#w2v7789 = pd.read_csv('w2v송민규1.csv', encoding='cp949')
w2v7933 = pd.read_csv('w2v7933.csv', encoding='cp949')
Dnn_w2v_7800 = pd.read_csv('Dnn_w2v7800.csv', encoding='cp949')
Dae_us_7971 = pd.read_csv('DAE_us_7971.csv', encoding='cp949')
score7644 = pd.read_csv('22(7644).csv',encoding='cp949') # 11


# 0.8이상 Ensemble submissions
score8091 = pd.read_csv('score7988 + w2v7932 + DAE7971.csv', encoding='cp949')
score8012 = pd.read_csv('score7977 + w2v_7913 + Dnn7982 + Cnn7974.csv', encoding='cp949')
score8062 = pd.read_csv('score7981, score7977, score7988, Dnn7982, Dae7971, Cnn7974.csv', encoding='cp949')
score8056 = pd.read_csv('esem8040, w2v_7913, Dnn7982, Dae7971, Cnn7974.csv', encoding='cp949')
score8043 = pd.read_csv('score7988, w2v_7883, Dae7971, ml_7880.csv', encoding='cp949')

# 민준 앙상블
score8070 = pd.read_csv('score8070.csv', encoding='cp949')
score8073 = pd.read_csv('score8073.csv', encoding='cp949')
score8074 = pd.read_csv('score8074.csv', encoding='cp949')
score8084 = pd.read_csv('score8084.csv', encoding='cp949')
score80780 = pd.read_csv('score80780.csv', encoding='cp949')
score80783 = pd.read_csv('score80783.csv', encoding='cp949')

# 민규 앙상블
score8085 = pd.read_csv('score8085.csv', encoding='cp949')
score8090 = pd.read_csv('score8090.csv', encoding='cp949')
score8095 = pd.read_csv('score8095.csv', encoding='cp949')

# %%
# gender 이름 바꾸기전

submissions = [
    
# 그룹과제 1등, 2등, 3등
    score7981, score7977, score7988,
    
# 개인과제2 1등, 2등, 3등
    w2v_7932, w2v_7913, w2v_7883,

# NN과제 1등, 2등, 3등
    esem8055, esem8040, esem8031,

# NN만점과제
    Dnn7982, Dae7971, Cnn7974,

# 우리과제
    ml_7880, ml_7868, ml_7830, w2v7789, w2v7894, Dnn_w2v_7800, Dae_us_7971,
    
# 앙상블된 서브미션
    score8091, score8012, score8062, score8056, score8043,
    score8070, score8073, score8074, score8084, score80780, score80783,
    score8085, score8090, score8095
    
              ]
print(len(submissions))

names= [
    
# 그룹과제 1등, 2등, 3등
    'score7981', 'score7977', 'score7988',
    
# 개인과제2 1등, 2등, 3등
    'w2v_7932' ,'w2v_7913' ,'w2v_7883',

# NN과제 1등, 2등, 3등
    'esem8055', 'esem8040', 'esem8031',

# NN만점과제
    'Dnn7982', 'Dae7971', 'Cnn7974',

# 우리과제
    'ml_7880', 'ml_7868', 'ml_7830', 'w2v7789', 'w2v7894', 'Dnn_w2v_7800', 'Dae_us_7971',

# 앙상블된 서브미션
    'score8091', 'score8012', 'score8062', 'score8056', 'score8043',
    'score8070', 'score8073', 'score8074', 'score8084', 'score80780', 'score80783',
    'score8085', 'score8090', 'score8095'
    
       ]
# Out:
# 33

# %% [markdown]
# # restart

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
from matplotlib import font_manager, rc
# %matplotlib inline

import platform
your_os = platform.system()
if your_os == 'Linux':
    rc('font', family='NanumGothic')
elif your_os == 'Windows':
    ttf = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=ttf).get_name()
    rc('font', family=font_name)
elif your_os == 'Darwin':
    rc('font', family='AppleGothic')
rc('axes', unicode_minus=False)

# %%
## Baseline: 0.80985

# 그룹과제 1등, 2등, 3등
score7981 = pd.read_csv('박혜지(7981).csv', encoding='cp949') # 14
score7977 = pd.read_csv('서진영(7977).csv', encoding='cp949') # 18
score7988 = pd.read_csv('홍재성(7988).csv', encoding='cp949') # 19

# 개인과제2 1등, 2등, 3등
w2v_7932 = pd.read_csv('김세홍(7932).csv', encoding='cp949')
w2v_7913 = pd.read_csv('권오현(7913).csv', encoding='cp949')
w2v_7883 = pd.read_csv('오주영(7883).csv', encoding='cp949')

# NN과제 1등, 2등, 3등
esem8055 = pd.read_csv('yj8055.csv', encoding='cp949')
esem8040 = pd.read_csv('hong8040.csv', encoding='cp949')
esem8031 = pd.read_csv('jin8031.csv', encoding='cp949')

# NN만점과제
Dnn7982 = pd.read_csv('Dnn7982.csv', encoding='cp949')
Dae7971 = pd.read_csv('DAE7971.csv', encoding='cp949')
Cnn7974 = pd.read_csv('Cnn17974.csv', encoding='cp949')

# 우리과제
#ml_7880 = pd.read_csv('18logreg2(7880).csv', encoding='cp949')
#ml_7868 = pd.read_csv('20logreg3(7868).csv', encoding='cp949')
#ml_7830 = pd.read_csv('jun7830.csv', encoding='cp949')
#w2v7789 = pd.read_csv('w2v송민규1.csv', encoding='cp949')
w2v8021 = pd.read_csv('w2v_7883, w2v_7932, w2v_7894.csv', encoding='cp949')
w2v7933 = pd.read_csv('w2v7933.csv', encoding='cp949')
#Dnn_w2v_7800 = pd.read_csv('Dnn_w2v7800.csv', encoding='cp949')
#Dae_us_7971 = pd.read_csv('DAE_us_7971.csv', encoding='cp949')

# # 0.8이상 Ensemble submissions
# score8091 = pd.read_csv('score7988 + w2v7932 + DAE7971.csv', encoding='cp949')
# score8012 = pd.read_csv('score7977 + w2v_7913 + Dnn7982 + Cnn7974.csv', encoding='cp949')
# score8062 = pd.read_csv('score7981, score7977, score7988, Dnn7982, Dae7971, Cnn7974.csv', encoding='cp949')
# score8056 = pd.read_csv('esem8040, w2v_7913, Dnn7982, Dae7971, Cnn7974.csv', encoding='cp949')
# score8043 = pd.read_csv('score7988, w2v_7883, Dae7971, ml_7880.csv', encoding='cp949')

# # 민준 앙상블
# score8070 = pd.read_csv('score8070.csv', encoding='cp949')
# score8073 = pd.read_csv('score8073.csv', encoding='cp949')
# score8074 = pd.read_csv('score8074.csv', encoding='cp949')
# score8084 = pd.read_csv('score8084.csv', encoding='cp949')
# score80780 = pd.read_csv('score80780.csv', encoding='cp949')
# score80783 = pd.read_csv('score80783.csv', encoding='cp949')

# # 민규 앙상블
# score8085 = pd.read_csv('score8085.csv', encoding='cp949')
# score8090 = pd.read_csv('score8090.csv', encoding='cp949')
# score8095 = pd.read_csv('score8095.csv', encoding='cp949')

# ensemble submissions
score8066 = pd.read_csv('w2v7933, score7977, Dnn7982, Dae7971.csv', encoding='cp949')
baseline8092 = pd.read_csv('baseline8092.csv', encoding='cp949')
sota3_8060 = pd.read_csv('sota3.csv', encoding='cp949')
ML123_8049 = pd.read_csv('score7988, score7981, score7977.csv', encoding='cp949')
esem123 = pd.read_csv('esem123.csv', encoding='cp949')
ML123W2V123_new = pd.read_csv('score7988, score7981, score7977, w2v7933, w2v_7932, w2v_7883.csv', encoding='cp949')
sota3esem3 = pd.read_csv('sota3esem3.csv', encoding='cp949')
newbase = pd.read_csv('esem8055 ,esem8040, Dnn7982, Dae7971, Cnn7974.csv',encoding='cp949')
newbase_ML123 = pd.read_csv('newbase_ML123.csv', encoding='cp949')
esem12 = pd.read_csv('esem8055, esem8040.csv', encoding='cp949')
esem12_sota3_weight = pd.read_csv('esem12_sota3_weight.csv', encoding='cp949')
hong_new = pd.read_csv('홍재성_new.csv', encoding='cp949')
ML123_8055 = pd.read_csv('score7988, score7981, score7977.csv', encoding='cp949')

# %%
# gender 이름 바꾸기전

submissions = [
    
# ML - manual
    score7981, score7977, score7988,
    
# ML - W2V
#    w2v_7932, w2v_7913, w2v_7883,  w2v7933,

# NN - group
    esem8055, esem8040,

# NN - indiviual
    Dnn7982, Dae7971, Cnn7974,

# ALL - ensemble
    score8066,baseline8092, sota3_8060, ML123_8049, esem123, w2v8021,ML123W2V123_new,sota3esem3, newbase, newbase_ML123,
    esem12, esem12_sota3_weight, hong_new, ML123_8055

    
              ]
print(len(submissions))

names= [
    
# ML - manual
    'score7981', 'score7977', 'score7988',
    
# ML - W2V
#    'w2v_7932', 'w2v_7913', 'w2v_7883',  'w2v7933',

# NN - group
    'esem8055', 'esem8040', 

# NN - indiviual
    'Dnn7982', 'Dae7971', 'Cnn7974', 

# ALL - ensemble
    'score8066', 'baseline8092','sota3_8060','ML123_8049','esem123', 'w2v8021','ML123W2V123_new','sota3esem3', 'newbase',
    'newbase_ML123', 'esem12','esem12_sota3_weight', 'hong_new', 'ML123_8055'

    
       ]
# Out:
# 22

# %%
# 각 submission별 gender 칼럼명 변경

for i in range(len(submissions)):
    

    submissions[i].rename(columns={'gender':f'{names[i]}'}, inplace=True)

# %%
        n=1

        for submission in submissions:

            print(n); n +=1
    
    display(submission)
# Out:
# 1
#       cust_id  score7981
# 0        3500   0.703970
# 1        3501   0.261014
# 2        3502   0.223002
# 3        3503   0.298456
# 4        3504   0.477007
# ...       ...        ...
# 2477     5977   0.476866
# 2478     5978   0.397060
# 2479     5979   0.783580
# 2480     5980   0.425649
# 2481     5981   0.544029
#
# [2482 rows x 2 columns]
# 2
#       cust_id  score7977
# 0        3500   0.838103
# 1        3501   0.148406
# 2        3502   0.126179
# 3        3503   0.195933
# 4        3504   0.401645
# ...       ...        ...
# 2477     5977   0.585520
# 2478     5978   0.361859
# 2479     5979   0.742040
# 2480     5980   0.381033
# 2481     5981   0.528198
#
# [2482 rows x 2 columns]
# 3
#       cust_id  score7988
# 0        3500   0.743568
# 1        3501   0.361648
# 2        3502   0.198195
# 3        3503   0.207855
# 4        3504   0.396858
# ...       ...        ...
# 2477     5977   0.421573
# 2478     5978   0.404951
# 2479     5979   0.763675
# ...

# %%
# 데이터 합치기

data = pd.DataFrame({'cust_id': range(3500,5982)})
for sub in submissions :
    data = pd.merge(data, sub, how='left', on='cust_id')
display(data)
data.info()
# Out:
#       cust_id  score7981  score7977  score7988  esem8055  esem8040   Dnn7982  \
# 0        3500   0.703970   0.838103   0.743568  0.783190  0.705826  0.718546
# 1        3501   0.261014   0.148406   0.361648  0.249035  0.267778  0.246766
# 2        3502   0.223002   0.126179   0.198195  0.206842  0.205548  0.178112
# 3        3503   0.298456   0.195933   0.207855  0.242358  0.279232  0.578469
# 4        3504   0.477007   0.401645   0.396858  0.341752  0.461922  0.621076
# ...       ...        ...        ...        ...       ...       ...       ...
# 2477     5977   0.476866   0.585520   0.421573  0.616425  0.477228  0.633926
# 2478     5978   0.397060   0.361859   0.404951  0.344216  0.423558  0.266491
# 2479     5979   0.783580   0.742040   0.763675  0.785444  0.734557  0.755670
# 2480     5980   0.425649   0.381033   0.578213  0.402934  0.424679  0.398160
# 2481     5981   0.544029   0.528198   0.632406  0.523529  0.594811  0.672710
#
# ...

# %%
data = data.drop('cust_id', axis=1); data
# Out:
#       score7981  score7977  score7988  esem8055  esem8040   Dnn7982   Dae7971  \
# 0      0.703970   0.838103   0.743568  0.783190  0.705826  0.718546  0.571990
# 1      0.261014   0.148406   0.361648  0.249035  0.267778  0.246766  0.241759
# 2      0.223002   0.126179   0.198195  0.206842  0.205548  0.178112  0.150302
# 3      0.298456   0.195933   0.207855  0.242358  0.279232  0.578469  0.306411
# 4      0.477007   0.401645   0.396858  0.341752  0.461922  0.621076  0.486499
# ...         ...        ...        ...       ...       ...       ...       ...
# 2477   0.476866   0.585520   0.421573  0.616425  0.477228  0.633926  0.480310
# 2478   0.397060   0.361859   0.404951  0.344216  0.423558  0.266491  0.477930
# 2479   0.783580   0.742040   0.763675  0.785444  0.734557  0.755670  0.591918
# 2480   0.425649   0.381033   0.578213  0.402934  0.424679  0.398160  0.386131
# 2481   0.544029   0.528198   0.632406  0.523529  0.594811  0.672710  0.502319
#
# ...

# %%
# 서브미션간 상관관계 히트맵

plt.figure(figsize=(20,11))
sns.heatmap(data.corr(), annot=True, cmap='RdYlBu_r', linewidths=0.2)
plt.show()

# %% [markdown]
# ML123 p.25

# %%
score7988, score7981, score7977

# %%
submission_list = [score7988, score7981, score7977]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 2.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 2.5)


fname = 'score7988, score7981, score7977.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'score7988, score7981, score7977.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.765004
# 1        3501  0.277726
# 2        3502  0.189063
# 3        3503  0.240790
# 4        3504  0.427560
# ...       ...       ...
# 2477     5977  0.501667
# 2478     5978  0.388631
# 2479     5979  0.763381
# 2480     5980  0.473180
# 2481     5981  0.570999
#
# [2482 rows x 2 columns]

# %%
ML123_8055 = pd.read_csv('score7988, score7981, score7977.csv', encoding='cp949')

# %% [markdown]
# ML123_8055 : [(3 + 2) + 1]

# %%
score7988, score7981, score7977

# %%
submission_list = [score7981, score7977]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 2.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 2.5)


fname = 'score7981, score7977.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'score7981, score7977.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.775392
# 1        3501  0.215848
# 2        3502  0.184238
# 3        3503  0.254975
# 4        3504  0.441739
# ...       ...       ...
# 2477     5977  0.535335
# 2478     5978  0.380071
# 2479     5979  0.763234
# 2480     5980  0.404265
# 2481     5981  0.536201
#
# [2482 rows x 2 columns]

# %%
ML23_25 = pd.read_csv('score7981, score7977.csv', encoding='cp949')

# %%
submission_list = [ML23_25, score7988]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 2.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 2.5)


fname = 'ML23_25, score7988.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'ML23_25, score7988.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.759730
# 1        3501  0.302069
# 2        3502  0.191407
# 3        3503  0.233203
# 4        3504  0.420198
# ...       ...       ...
# 2477     5977  0.483484
# 2478     5978  0.392807
# 2479     5979  0.763455
# 2480     5980  0.502583
# 2481     5981  0.587262
#
# [2482 rows x 2 columns]

# %%
ML123_con25_8055 = pd.read_csv('ML23_25, score7988.csv', encoding='cp949')

# %% [markdown]
# esem12 : p값 조절

# %%
esem8055, esem8040
# Out:
# (      cust_id  esem8055
#  0        3500  0.783190
#  1        3501  0.249035
#  2        3502  0.206842
#  3        3503  0.242358
#  4        3504  0.341752
#  ...       ...       ...
#  2477     5977  0.616425
#  2478     5978  0.344216
#  2479     5979  0.785444
#  2480     5980  0.402934
#  2481     5981  0.523529
#
#  [2482 rows x 2 columns],
#        cust_id  esem8040
#  0        3500  0.705826
#  1        3501  0.267778
#  2        3502  0.205548
#  3        3503  0.279232
#  4        3504  0.461922
#  ...       ...       ...
#  2477     5977  0.477228
#  2478     5978  0.423558
#  2479     5979  0.734557
#  2480     5980  0.424679
#  2481     5981  0.594811
#
#  [2482 rows x 2 columns])

# %%
submission_list = [esem8055, esem8040]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 7.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 7.5)


fname = 'esem8055, esem8040.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'esem8055, esem8040.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.750895
# 1        3501  0.259499
# 2        3502  0.206202
# 3        3503  0.264863
# 4        3504  0.426756
# ...       ...       ...
# 2477     5977  0.572359
# 2478     5978  0.396154
# 2479     5979  0.762743
# 2480     5980  0.414730
# 2481     5981  0.566311
#
# [2482 rows x 2 columns]

# %%
esem12_con75 = pd.read_csv('esem8055, esem8040.csv', encoding='cp949')

# %%
esem12_con75
# Out:
#       cust_id    gender
# 0        3500  0.750895
# 1        3501  0.259499
# 2        3502  0.206202
# 3        3503  0.264863
# 4        3504  0.426756
# ...       ...       ...
# 2477     5977  0.572359
# 2478     5978  0.396154
# 2479     5979  0.762743
# 2480     5980  0.414730
# 2481     5981  0.566311
#
# [2482 rows x 2 columns]

# %% [markdown]
# esem12_con75_sota3_weight_ML123_con25

# %%
esem12_con75_sota3_weight = esem12_con75['gender'] * 0.6 + sota3_8060['sota3_8060'] * 0.4

# %%
pred = esem12_con75_sota3_weight * 0.85 + ML123_con25_8055['gender'] * 0.15

# %%
esem12_con75_sota3_weight_ML123_con25 = pd.DataFrame({'cust_id':range(3500, 5982), 'gender':pred})
esem12_con75_sota3_weight_ML123_con25.to_csv('esem12_con75_sota3_weight_ML123_con25.csv', encoding='cp949', index=False)
esem12_con75_sota3_weight_ML123_con25
# Out:
#       cust_id    gender
# 0        3500  0.715042
# 1        3501  0.271338
# 2        3502  0.241215
# 3        3503  0.324521
# 4        3504  0.463545
# ...       ...       ...
# 2477     5977  0.545325
# 2478     5978  0.398549
# 2479     5979  0.721988
# 2480     5980  0.422449
# 2481     5981  0.574253
#
# [2482 rows x 2 columns]

# %% [markdown]
# esem12_con115_sota3_weight_ML123_con25

# %% [markdown]
# esem12 : p값 조절 -> 7.5

# %%
submission_list = [esem8055, esem8040]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 11.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 11.5)


fname = 'esem8055, esem8040_con115.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'esem8055, esem8040_con115.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.754515
# 1        3501  0.260144
# 2        3502  0.206206
# 3        3503  0.267026
# 4        3504  0.436069
# ...       ...       ...
# 2477     5977  0.582966
# 2478     5978  0.401848
# 2479     5979  0.764372
# 2480     5980  0.415285
# 2481     5981  0.570206
#
# [2482 rows x 2 columns]

# %%
esem12_con115 = pd.read_csv('esem8055, esem8040_con115.csv', encoding='cp949')

# %% [markdown]
# esem12_con115_sota3_weight_ML123_con25

# %%
esem12_con115_sota3_weight = esem12_con115['gender'] * 0.6 + sota3_8060['sota3_8060'] * 0.4

# %%
pred = esem12_con115_sota3_weight * 0.85 + ML123_con25_8055['gender'] * 0.15

# %%
esem12_con115_sota3_weight_ML123_con25 = pd.DataFrame({'cust_id':range(3500, 5982), 'gender':pred})
esem12_con115_sota3_weight_ML123_con25.to_csv('esem12_con115_sota3_weight_ML123_con25.csv', encoding='cp949', index=False)
esem12_con115_sota3_weight_ML123_con25
# Out:
#       cust_id    gender
# 0        3500  0.716888
# 1        3501  0.271667
# 2        3502  0.241217
# 3        3503  0.325625
# 4        3504  0.468294
# ...       ...       ...
# 2477     5977  0.550735
# 2478     5978  0.401453
# 2479     5979  0.722819
# 2480     5980  0.422732
# 2481     5981  0.576239
#
# [2482 rows x 2 columns]

# %% [markdown]
# cnn 비교

# %%
pd.concat([Cnn7974[:60].drop('cust_id', axis=1), cnn76[:60].drop('cust_id', axis=1)], axis=1)
# Out:
#      Cnn7974    gender
# 0   0.611167  0.659372
# 1   0.319969  0.362751
# 2   0.423284  0.441150
# 3   0.354171  0.459171
# 4   0.473791  0.506335
# 5   0.302804  0.287436
# 6   0.260836  0.325880
# 7   0.595712  0.602758
# 8   0.395887  0.424545
# 9   0.283918  0.301711
# 10  0.310768  0.272489
# 11  0.421480  0.413644
# 12  0.403668  0.459662
# 13  0.303560  0.306100
# 14  0.533040  0.605676
# 15  0.271324  0.280243
# 16  0.263496  0.264818
# 17  0.282057  0.274524
# 18  0.327898  0.382472
# 19  0.493549  0.476710
# 20  0.587741  0.671230
# 21  0.457018  0.511436
# 22  0.496516  0.514663
# 23  0.332918  0.338030
# 24  0.254021  0.263046
# 25  0.574393  0.554093
# 26  0.271387  0.287905
# 27  0.695109  0.759597
# 28  0.365289  0.458450
# 29  0.342065  0.349101
# 30  0.316868  0.336138
# 31  0.610789  0.709583
# 32  0.257225  0.249997
# 33  0.321511  0.363757
# 34  0.494751  0.496767
# 35  0.285513  0.313308
# 36  0.333402  0.369504
# 37  0.588795  0.632755
# 38  0.397184  0.452194
# ...

# %%
Cnn7974
# Out:
#       cust_id   Cnn7974
# 0        3500  0.611167
# 1        3501  0.319969
# 2        3502  0.423284
# 3        3503  0.354171
# 4        3504  0.473791
# ...       ...       ...
# 2477     5977  0.424815
# 2478     5978  0.402117
# 2479     5979  0.522821
# 2480     5980  0.410776
# 2481     5981  0.528627
#
# [2482 rows x 2 columns]

# %%
cnn76 = pd.read_csv('submission76.csv', encoding='cp949')
cnn76
# Out:
#       cust_id    gender
# 0        3500  0.659372
# 1        3501  0.362751
# 2        3502  0.441150
# 3        3503  0.459171
# 4        3504  0.506335
# ...       ...       ...
# 2477     5977  0.450165
# 2478     5978  0.422518
# 2479     5979  0.589788
# 2480     5980  0.394906
# 2481     5981  0.565504
#
# [2482 rows x 2 columns]

# %%
cnn77 = pd.read_csv('submission77.csv', encoding='cp949')
cnn77
# Out:
#       cust_id    gender
# 0        3500  0.647464
# 1        3501  0.367357
# 2        3502  0.431249
# 3        3503  0.428472
# 4        3504  0.509623
# ...       ...       ...
# 2477     5977  0.446778
# 2478     5978  0.433182
# 2479     5979  0.577522
# 2480     5980  0.388203
# 2481     5981  0.583586
#
# [2482 rows x 2 columns]

# %% [markdown]
# sota3_cnn76

# %%
Dnn7982, Dae7971, cnn76
# Out:
#       cust_id   Dae7971
# 0        3500  0.571990
# 1        3501  0.241759
# 2        3502  0.150302
# 3        3503  0.306411
# 4        3504  0.486499
# ...       ...       ...
# 2477     5977  0.480310
# 2478     5978  0.477930
# 2479     5979  0.591918
# 2480     5980  0.386131
# 2481     5981  0.502319
#
# [2482 rows x 2 columns]

# %%
submission_list = [Dae7971, cnn76]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 11.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 11.5)


fname = 'Dae7971, cnn76_con.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'Dae7971, cnn76_con.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.630494
# 1        3501  0.341810
# 2        3502  0.415346
# 3        3503  0.432670
# 4        3504  0.497449
# ...       ...       ...
# 2477     5977  0.467747
# 2478     5978  0.458547
# 2479     5979  0.590863
# 2480     5980  0.390777
# 2481     5981  0.543084
#
# [2482 rows x 2 columns]

# %%
sota2_con = pd.read_csv('Dae7971, cnn76_con.csv', encoding='cp949')

# %%
sota2_con, Dnn7982
# Out:
#       cust_id    gender
# 0        3500  0.630494
# 1        3501  0.341810
# 2        3502  0.415346
# 3        3503  0.432670
# 4        3504  0.497449
# ...       ...       ...
# 2477     5977  0.467747
# 2478     5978  0.458547
# 2479     5979  0.590863
# 2480     5980  0.390777
# 2481     5981  0.543084
#
# [2482 rows x 2 columns]

# %%
submission_list = [sota2_con, Dnn7982]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 11.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 11.5)


fname = 'sota2_con, Dnn7982_con.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'sota2_con, Dnn7982_con.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.688432
# 1        3501  0.322470
# 2        3502  0.391053
# 3        3503  0.546284
# 4        3504  0.588574
# ...       ...       ...
# 2477     5977  0.598397
# 2478     5978  0.431798
# 2479     5979  0.715027
# 2480     5980  0.394650
# 2481     5981  0.637885
#
# [2482 rows x 2 columns]

# %%
sota3_con = pd.read_csv('sota2_con, Dnn7982_con.csv', encoding='cp949')

# %%
esem12_con115_sota3_con_weight = esem12_con115['gender'] * 0.6  + sota3_con['gender'] * 0.4

# %%
pred = esem12_con115_sota3_con_weight * 0.85 + ML123_con25_8055['gender'] * 0.15

# %%
esem12_con115_sota3_con_weight_ML123_con25 = pd.DataFrame({'cust_id':range(3500, 5982), 'gender':pred})
esem12_con115_sota3_con_weight_ML123_con25.to_csv('esem12_con115_sota3_con_weight_ML123_con25.csv', encoding='cp949', index=False)
esem12_con115_sota3_con_weight_ML123_con25
# Out:
#       cust_id    gender
# 0        3500  0.732829
# 1        3501  0.287624
# 2        3502  0.266834
# 3        3503  0.356901
# 4        3504  0.485540
# ...       ...       ...
# 2477     5977  0.573290
# 2478     5978  0.410675
# 2479     5979  0.747457
# 2480     5980  0.421364
# 2481     5981  0.595775
#
# [2482 rows x 2 columns]

# %% [markdown]
# new sota: sota3_con_with_w2v8021

# %%
Dae7971, Cnn7974
# Out:
# (      cust_id   Dae7971
#  0        3500  0.571990
#  1        3501  0.241759
#  2        3502  0.150302
#  3        3503  0.306411
#  4        3504  0.486499
#  ...       ...       ...
#  2477     5977  0.480310
#  2478     5978  0.477930
#  2479     5979  0.591918
#  2480     5980  0.386131
#  2481     5981  0.502319
#
#  [2482 rows x 2 columns],
#        cust_id   Cnn7974
#  0        3500  0.611167
#  1        3501  0.319969
#  2        3502  0.423284
#  3        3503  0.354171
#  4        3504  0.473791
#  ...       ...       ...
#  2477     5977  0.424815
#  2478     5978  0.402117
#  2479     5979  0.522821
#  2480     5980  0.410776
#  2481     5981  0.528627
#
#  [2482 rows x 2 columns])

# %%
submission_list = [Dae7971, Cnn7974]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 2.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 2.5)


fname = 'Dae7971, Cnn7974_con.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'Dae7971, Cnn7974_con.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.592064
# 1        3501  0.284902
# 2        3502  0.330221
# 3        3503  0.331582
# 4        3504  0.480208
# ...       ...       ...
# 2477     5977  0.453836
# 2478     5978  0.442462
# 2479     5979  0.558972
# 2480     5980  0.398739
# 2481     5981  0.515725
#
# [2482 rows x 2 columns]

# %%
sota2_con = pd.read_csv('Dae7971, Cnn7974_con.csv', encoding='cp949')

# %%
submission_list = [sota2_con, Dnn7982]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 2.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 2.5)


fname = 'sota2_con, Dnn7982_con.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'sota2_con, Dnn7982_con.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.659858
# 1        3501  0.266857
# 2        3502  0.270415
# 3        3503  0.479136
# 4        3504  0.557336
# ...       ...       ...
# 2477     5977  0.554888
# 2478     5978  0.370301
# 2479     5979  0.668216
# 2480     5980  0.398450
# 2481     5981  0.601916
#
# [2482 rows x 2 columns]

# %%
sota3_con = pd.read_csv('sota2_con, Dnn7982_con.csv', encoding='cp949')

# %%
sota3_con
# Out:
#       cust_id    gender
# 0        3500  0.659858
# 1        3501  0.266857
# 2        3502  0.270415
# 3        3503  0.479136
# 4        3504  0.557336
# ...       ...       ...
# 2477     5977  0.554888
# 2478     5978  0.370301
# 2479     5979  0.668216
# 2480     5980  0.398450
# 2481     5981  0.601916
#
# [2482 rows x 2 columns]

# %%
w2v8021
# Out:
#       cust_id   w2v8021
# 0        3500  0.702567
# 1        3501  0.226553
# 2        3502  0.247087
# 3        3503  0.279563
# 4        3504  0.399995
# ...       ...       ...
# 2477     5977  0.410180
# 2478     5978  0.307057
# 2479     5979  0.731491
# 2480     5980  0.426476
# 2481     5981  0.648234
#
# [2482 rows x 2 columns]

# %%
submission_list = [sota3_con, w2v8021]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 2.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 2.5)


fname = 'sota3_con, w2v8021_con.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'sota3_con, w2v8021_con.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.681714
# 1        3501  0.247935
# 2        3502  0.259145
# 3        3503  0.398292
# 4        3504  0.488214
# ...       ...       ...
# 2477     5977  0.490566
# 2478     5978  0.340882
# 2479     5979  0.700925
# 2480     5980  0.412820
# 2481     5981  0.625718
#
# [2482 rows x 2 columns]

# %%
sota4_con25 = pd.read_csv('sota3_con, w2v8021_con.csv', encoding='cp949')

# %%
esem12_con115_sota4_con25_weight = esem12_con115['gender'] * 0.6  + sota4_con25['gender'] * 0.4

# %%
pred = esem12_con115_sota4_con25_weight * 0.85 + ML123_con25_8055['gender'] * 0.15

# %%
esem12_con115_sota4_con25_weight_ML123_con25 = pd.DataFrame({'cust_id':range(3500, 5982), 'gender':pred})
esem12_con115_sota4_con25_weight_ML123_con25.to_csv('esem12_con115_sota4_con25_weight_ML123_con25.csv', encoding='cp949', index=False)
esem12_con115_sota4_con25_weight_ML123_con25
# Out:
#       cust_id    gender
# 0        3500  0.730545
# 1        3501  0.262282
# 2        3502  0.221985
# 3        3503  0.306583
# 4        3504  0.451418
# ...       ...       ...
# 2477     5977  0.536628
# 2478     5978  0.379764
# 2479     5979  0.742663
# 2480     5980  0.427542
# 2481     5981  0.591638
#
# [2482 rows x 2 columns]

# %% [markdown]
# ML2_new power_mean: 2.5

# %%
ohe_sub = pd.read_csv('ohe_sub.csv', encoding='cp949')
mean_sub = pd.read_csv('mean_sub.csv', encoding='cp949')
avg_sub = pd.read_csv('avg_submission.csv', encoding='cp949')

# %%
ohe_sub, mean_sub, avg_sub
# Out:
# (      cust_id    gender
#  0        3500  0.623550
#  1        3501  0.253105
#  2        3502  0.327921
#  3        3503  0.273711
#  4        3504  0.497948
#  ...       ...       ...
#  2477     5977  0.463175
#  2478     5978  0.372994
#  2479     5979  0.818638
#  2480     5980  0.419606
#  2481     5981  0.496100
#
#  [2482 rows x 2 columns],
#        cust_id    gender
#  0        3500  0.733214
#  1        3501  0.281393
#  2        3502  0.300314
#  3        3503  0.266484
#  4        3504  0.494388
#  ...       ...       ...
#  2477     5977  0.463793
#  2478     5978  0.420531
#  2479     5979  0.812680
#  2480     5980  0.447283
#  2481     5981  0.504682
#
#  [2482 rows x 2 columns],
#        cust_id    gender
#  0        3500  0.763063
#  1        3501  0.249675
#  2        3502  0.112611
#  3        3503  0.364481
#  4        3504  0.440881
#  ...       ...       ...
#  2477     5977  0.504800
#  2478     5978  0.399088
#  2479     5979  0.723168
# ...

# %%
submission_list = [ohe_sub, mean_sub, avg_sub]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 2.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 2.5)


fname = 'ohe_sub, mean_sub, avg_sub.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'ohe_sub, mean_sub, avg_sub.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.710380
# 1        3501  0.261973
# 2        3502  0.271531
# 3        3503  0.306524
# 4        3504  0.478800
# ...       ...       ...
# 2477     5977  0.477854
# 2478     5978  0.398249
# 2479     5979  0.786636
# 2480     5980  0.426352
# 2481     5981  0.554205
#
# [2482 rows x 2 columns]

# %%
ML2 = pd.read_csv('ohe_sub, mean_sub, avg_sub.csv', encoding='cp949')

# %%
score7988
# Out:
#       cust_id  score7988
# 0        3500   0.743568
# 1        3501   0.361648
# 2        3502   0.198195
# 3        3503   0.207855
# 4        3504   0.396858
# ...       ...        ...
# 2477     5977   0.421573
# 2478     5978   0.404951
# 2479     5979   0.763675
# 2480     5980   0.578213
# 2481     5981   0.632406
#
# [2482 rows x 2 columns]

# %%
ML2
# Out:
#       cust_id    gender
# 0        3500  0.710380
# 1        3501  0.261973
# 2        3502  0.271531
# 3        3503  0.306524
# 4        3504  0.478800
# ...       ...       ...
# 2477     5977  0.477854
# 2478     5978  0.398249
# 2479     5979  0.786636
# 2480     5980  0.426352
# 2481     5981  0.554205
#
# [2482 rows x 2 columns]

# %%
ML3 = pd.read_csv('서진영pm25.csv', encoding='cp949')

# %%
score7988, ML2, ML3
# Out:
#       cust_id    gender
# 0        3500  0.659858
# 1        3501  0.266857
# 2        3502  0.270415
# 3        3503  0.479136
# 4        3504  0.557336
# ...       ...       ...
# 2477     5977  0.554888
# 2478     5978  0.370301
# 2479     5979  0.668216
# 2480     5980  0.398450
# 2481     5981  0.601916
#
# [2482 rows x 2 columns]

# %%
submission_list = [ML2, ML3]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 2.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 2.5)


fname = 'ML2, ML3.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'ML2, ML3.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.778182
# 1        3501  0.216610
# 2        3502  0.217673
# 3        3503  0.260221
# 4        3504  0.445137
# ...       ...       ...
# 2477     5977  0.536030
# 2478     5978  0.380828
# 2479     5979  0.765302
# 2480     5980  0.407301
# 2481     5981  0.541694
#
# [2482 rows x 2 columns]

# %%
ML23_con = pd.read_csv('ML2, ML3.csv', encoding='cp949')

# %%
submission_list = [score7988, ML23_con]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 2.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 2.5)


fname = 'score7988, ML23_con.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'score7988, ML23_con.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.761170
# 1        3501  0.302300
# 2        3502  0.208275
# 3        3503  0.236219
# 4        3504  0.422034
# ...       ...       ...
# 2477     5977  0.483890
# 2478     5978  0.393167
# 2479     5979  0.764490
# 2480     5980  0.503683
# 2481     5981  0.589669
#
# [2482 rows x 2 columns]

# %%
ML123_pm_con25 = pd.read_csv('score7988, ML23_con.csv', encoding='cp949')

# %%
sota3_con
# Out:
#       cust_id    gender
# 0        3500  0.659858
# 1        3501  0.266857
# 2        3502  0.270415
# 3        3503  0.479136
# 4        3504  0.557336
# ...       ...       ...
# 2477     5977  0.554888
# 2478     5978  0.370301
# 2479     5979  0.668216
# 2480     5980  0.398450
# 2481     5981  0.601916
#
# [2482 rows x 2 columns]

# %%
esem12_con115_sota3_con_weight = esem12_con115['gender'] * 0.6  + sota3_con['gender'] * 0.4

# %%
pred = esem12_con115_sota3_con_weight * 0.85 + ML123_pm_con25['gender'] * 0.15

# %%
esem12_con115_sota3_con_weight_ML123_pm_con25 = pd.DataFrame({'cust_id':range(3500, 5982), 'gender':pred})
esem12_con115_sota3_con_weight_ML123_pm_con25.to_csv('esem12_con115_sota3_con_weight_ML123_pm_con25.csv', encoding='cp949', index=False)
esem12_con115_sota3_con_weight_ML123_pm_con25
# Out:
#       cust_id    gender
# 0        3500  0.723330
# 1        3501  0.268750
# 2        3502  0.228348
# 3        3503  0.334523
# 4        3504  0.475194
# ...       ...       ...
# 2477     5977  0.558558
# 2478     5978  0.389820
# 2479     5979  0.731697
# 2480     5980  0.422821
# 2481     5981  0.583907
#
# [2482 rows x 2 columns]

# %% [markdown]
# sota3_con35 변경, 성능 오르는지 봐서 sota에 con의 효과를 보기

# %%
submission_list = [Dae7971, Cnn7974]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 3.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 3.5)


fname = 'Dae7971, Cnn7974_con35.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'Dae7971, Cnn7974_con35.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.592388
# 1        3501  0.287481
# 2        3502  0.349857
# 3        3503  0.332432
# 4        3504  0.480250
# ...       ...       ...
# 2477     5977  0.454677
# 2478     5978  0.444061
# 2479     5979  0.560031
# 2480     5980  0.398929
# 2481     5981  0.515892
#
# [2482 rows x 2 columns]

# %%
sota2_con35 = pd.read_csv('Dae7971, Cnn7974_con35.csv', encoding='cp949')

# %%
submission_list = [sota2_con35, Dnn7982]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 3.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 3.5)


fname = 'sota2_con35, Dnn7982_con.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'sota2_con35, Dnn7982_con.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.662952
# 1        3501  0.269046
# 2        3502  0.294474
# 3        3503  0.493118
# 4        3504  0.561653
# ...       ...       ...
# 2477     5977  0.562045
# 2478     5978  0.380753
# 2479     5979  0.675460
# 2480     5980  0.398545
# 2481     5981  0.606908
#
# [2482 rows x 2 columns]

# %%
sota3_con35 = pd.read_csv('sota2_con35, Dnn7982_con.csv', encoding='cp949')

# %%
esem12_con115_sota3_con35_weight = esem12_con115['gender'] * 0.6  + sota3_con35['gender'] * 0.4

# %%
pred = esem12_con115_sota3_con35_weight * 0.85 + ML123_con25_8055['gender'] * 0.15

# %%
esem12_con115_sota3_con35_weight_ML123_con25 = pd.DataFrame({'cust_id':range(3500, 5982), 'gender':pred})
esem12_con115_sota3_con35_weight_ML123_con25.to_csv('esem12_con115_sota3_con35_weight_ML123_con25.csv', encoding='cp949', index=False)
esem12_con115_sota3_con35_weight_ML123_con25
# Out:
#       cust_id    gender
# 0        3500  0.724166
# 1        3501  0.269460
# 2        3502  0.233997
# 3        3503  0.338824
# 4        3504  0.476387
# ...       ...       ...
# 2477     5977  0.560930
# 2478     5978  0.393319
# 2479     5979  0.734005
# 2480     5980  0.422688
# 2481     5981  0.585243
#
# [2482 rows x 2 columns]

# %% [markdown]
# sota3의 p값을 3.5 -> 11.5  (안오를시 3.5고정)

# %%
submission_list = [Dnn7982, Dae7971, Cnn7974]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 11.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 11.5)


fname = 'Dnn7982, Dae7971, Cnn7974_115.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'Dnn7982, Dae7971, Cnn7974_115.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.664849
# 1        3501  0.293010
# 2        3502  0.384720
# 3        3503  0.525956
# 4        3504  0.569402
# ...       ...       ...
# 2477     5977  0.578673
# 2478     5978  0.439310
# 2479     5979  0.691139
# 2480     5980  0.399679
# 2481     5981  0.616376
#
# [2482 rows x 2 columns]

# %%
sota3_115 = pd.read_csv('Dnn7982, Dae7971, Cnn7974_115.csv', encoding='cp949')

# %%
esem12_con115_sota3_115_weight = esem12_con115['gender'] * 0.6  + sota3_115['gender'] * 0.4

# %%
pred = esem12_con115_sota3_115_weight * 0.85 + ML123_con25_8055['gender'] * 0.15

# %%
esem12_con115_sota3_115_weight_ML123_con25 = pd.DataFrame({'cust_id':range(3500, 5982), 'gender':pred})
esem12_con115_sota3_115_weight_ML123_con25.to_csv('esem12_con115_sota3_115_weight_ML123_con25.csv', encoding='cp949', index=False)
esem12_con115_sota3_115_weight_ML123_con25
# Out:
#       cust_id    gender
# 0        3500  0.724811
# 1        3501  0.277607
# 2        3502  0.264681
# 3        3503  0.349989
# 4        3504  0.479022
# ...       ...       ...
# 2477     5977  0.566584
# 2478     5978  0.413229
# 2479     5979  0.739335
# 2480     5980  0.423074
# 2481     5981  0.588462
#
# [2482 rows x 2 columns]

# %% [raw]
# 1. p값 11.5 바꾼걸로 제출
#     - esem12_con115_sota3_115_weight_ML123_con25 제출하여보기
# 2. 0.6, 0.4 가중치 조절 -> 0.65, 0.35
#     3- 오르면 -> 0.7, 0.3
#     3- 내리면 -> 0.55, 0.45
#     4- 내렸는데 오르면 -> 0.5, 0.5
# 5. 0.85, 0.15 가중치 조절 -> 0.8, 0.2
#     6 . 오르면 -> 0.75, 0.25
#     6 . 내리면 -> 0.9, 0.1

# %% [markdown]
# 0.6, 0.4 가중치 조절
#      - 1. 11.5일때
#      - 2. 3.5일때

# %% [markdown]
# **11.5일때**

# %%
esem12_con115_sota3_115_weight_6535 = esem12_con115['gender'] * 0.65  + sota3_115['gender'] * 0.35

# %%
pred = esem12_con115_sota3_115_weight_6535 * 0.85 + ML123_con25_8055['gender'] * 0.15

# %%
esem12_con115_sota3_115_weight_ML123_con25_6535 = pd.DataFrame({'cust_id':range(3500, 5982), 'gender':pred})
esem12_con115_sota3_115_weight_ML123_con25_6535.to_csv('esem12_con115_sota3_115_weight_ML123_con25_6535.csv', encoding='cp949', index=False)
esem12_con115_sota3_115_weight_ML123_con25_6535
# Out:
#       cust_id    gender
# 0        3500  0.728622
# 1        3501  0.276210
# 2        3502  0.257094
# 3        3503  0.338985
# 4        3504  0.473355
# ...       ...       ...
# 2477     5977  0.566766
# 2478     5978  0.411637
# 2479     5979  0.742448
# 2480     5980  0.423737
# 2481     5981  0.586500
#
# [2482 rows x 2 columns]

# %% [markdown]
# 6535 비율 X -> 내려서 5545 비율 진행

# %%
esem12_con115_sota3_115_weight_5545 = esem12_con115['gender'] * 0.55  + sota3_115['gender'] * 0.45

# %%
pred = esem12_con115_sota3_115_weight_5545 * 0.85 + ML123_con25_8055['gender'] * 0.15

# %%
esem12_con115_sota3_115_weight_ML123_con25_5545 = pd.DataFrame({'cust_id':range(3500, 5982), 'gender':pred})
esem12_con115_sota3_115_weight_ML123_con25_5545.to_csv('esem12_con115_sota3_115_weight_ML123_con25_5545.csv', encoding='cp949', index=False)
esem12_con115_sota3_115_weight_ML123_con25_5545
# Out:
#       cust_id    gender
# 0        3500  0.721000
# 1        3501  0.279004
# 2        3502  0.272268
# 3        3503  0.360994
# 4        3504  0.484688
# ...       ...       ...
# 2477     5977  0.566401
# 2478     5978  0.414821
# 2479     5979  0.736223
# 2480     5980  0.422410
# 2481     5981  0.590425
#
# [2482 rows x 2 columns]

# %% [markdown]
# ML123_con의 p값 조절: 2.5 -> 11.5

# %%
# 재료: esem12_con115, sota3_115, ML123_con25_8055 불러오기
esem12_con115 = pd.read_csv('esem8055, esem8040_con115.csv', encoding='cp949')
sota3_115 = pd.read_csv('Dnn7982, Dae7971, Cnn7974_115.csv', encoding='cp949')
ML123_con25_8055 = pd.read_csv('ML23_25, score7988.csv', encoding='cp949')

# %%
score7988, score7981, score7977
# Out:
# (      cust_id  score7988
#  0        3500   0.743568
#  1        3501   0.361648
#  2        3502   0.198195
#  3        3503   0.207855
#  4        3504   0.396858
#  ...       ...        ...
#  2477     5977   0.421573
#  2478     5978   0.404951
#  2479     5979   0.763675
#  2480     5980   0.578213
#  2481     5981   0.632406
#
#  [2482 rows x 2 columns],
#        cust_id  score7981
#  0        3500   0.703970
#  1        3501   0.261014
#  2        3502   0.223002
#  3        3503   0.298456
#  4        3504   0.477007
#  ...       ...        ...
#  2477     5977   0.476866
#  2478     5978   0.397060
#  2479     5979   0.783580
#  2480     5980   0.425649
#  2481     5981   0.544029
#
#  [2482 rows x 2 columns],
#        cust_id  score7977
#  0        3500   0.838103
#  1        3501   0.148406
#  2        3502   0.126179
#  3        3503   0.195933
#  4        3504   0.401645
#  ...       ...        ...
#  2477     5977   0.585520
#  2478     5978   0.361859
# ...

# %%
submission_list = [score7981, score7977]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 11.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 11.5)


fname = 'score7981, score7977_con_115.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'score7981, score7977_con_115.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.797790
# 1        3501  0.245779
# 2        3502  0.209984
# 3        3503  0.281191
# 4        3504  0.454196
# ...       ...       ...
# 2477     5977  0.555611
# 2478     5978  0.383566
# 2479     5979  0.765735
# 2480     5980  0.409444
# 2481     5981  0.536724
#
# [2482 rows x 2 columns]

# %%
ML23_con115 = pd.read_csv('score7981, score7977_con_115.csv', encoding='cp949')

# %%
submission_list = [ML23_con115, score7988]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 11.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 11.5)


fname = 'ML23_con115, score7988_con115.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'ML23_con115, score7988_con115.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.775562
# 1        3501  0.340841
# 2        3502  0.204968
# 3        3503  0.265446
# 4        3504  0.434833
# ...       ...       ...
# 2477     5977  0.524977
# 2478     5978  0.395758
# 2479     5979  0.764712
# 2480     5980  0.545278
# 2481     5981  0.602767
#
# [2482 rows x 2 columns]

# %%
ML123_con115 = pd.read_csv('ML23_con115, score7988_con115.csv', encoding='cp949')

# %%
esem12_con115_sota3_115_weight = esem12_con115['gender'] * 0.6  + sota3_115['gender'] * 0.4

# %%
pred = esem12_con115_sota3_115_weight * 0.85 + ML123_con115['gender'] * 0.15

# %%
esem12_con115_sota3_115_weight_ML123_con115 = pd.DataFrame({'cust_id':range(3500, 5982), 'gender':pred})
esem12_con115_sota3_115_weight_ML123_con115.to_csv('esem12_con115_sota3_115_weight_ML123_con115.csv', encoding='cp949', index=False)
esem12_con115_sota3_115_weight_ML123_con115
# Out:
#       cust_id    gender
# 0        3500  0.727186
# 1        3501  0.283423
# 2        3502  0.266715
# 3        3503  0.354825
# 4        3504  0.481217
# ...       ...       ...
# 2477     5977  0.572808
# 2478     5978  0.413672
# 2479     5979  0.739524
# 2480     5980  0.429478
# 2481     5981  0.590788
#
# [2482 rows x 2 columns]

# %% [markdown]
# 마지막 0.85, 0.15 비율의 조정
#      - 첫번째: 0.85, 0.15 -> 0.8, 0.2

# %%
esem12_con115_sota3_115_weight = esem12_con115['gender'] * 0.6  + sota3_115['gender'] * 0.4

# %%
pred = esem12_con115_sota3_115_weight * 0.8 + ML123_con25_8055['gender'] * 0.2

# %%
esem12_con115_sota3_115_weight_ML123_con25_8055_0802 = pd.DataFrame({'cust_id':range(3500, 5982), 'gender':pred})
esem12_con115_sota3_115_weight_ML123_con25_8055_0802.to_csv('esem12_con115_sota3_115_weight_ML123_con25_8055_0802.csv', encoding='cp949', index=False)
esem12_con115_sota3_115_weight_ML123_con25_8055_0802
# Out:
#       cust_id    gender
# 0        3500  0.726865
# 1        3501  0.279046
# 2        3502  0.260371
# 3        3503  0.343119
# 4        3504  0.475561
# ...       ...       ...
# 2477     5977  0.561696
# 2478     5978  0.412028
# 2479     5979  0.740754
# 2480     5980  0.427751
# 2481     5981  0.588392
#
# [2482 rows x 2 columns]

# %% [markdown]
# 마지막 0.85, 0.15 비율의 조정
#      - 두번째: 0.85, 0.15 -> 0.9, 0.1

# %%
esem12_con115_sota3_115_weight = esem12_con115['gender'] * 0.6  + sota3_115['gender'] * 0.4

# %%
pred = esem12_con115_sota3_115_weight * 0.9 + ML123_con25_8055['gender'] * 0.1

# %%
esem12_con115_sota3_115_weight_ML123_con25_8055_0901 = pd.DataFrame({'cust_id':range(3500, 5982), 'gender':pred})
esem12_con115_sota3_115_weight_ML123_con25_8055_0901.to_csv('esem12_con115_sota3_115_weight_ML123_con25_8055_0901.csv', encoding='cp949', index=False)
esem12_con115_sota3_115_weight_ML123_con25_8055_0901
# Out:
#       cust_id    gender
# 0        3500  0.722757
# 1        3501  0.276168
# 2        3502  0.268991
# 3        3503  0.356859
# 4        3504  0.482482
# ...       ...       ...
# 2477     5977  0.571472
# 2478     5978  0.414430
# 2479     5979  0.737917
# 2480     5980  0.418397
# 2481     5981  0.588533
#
# [2482 rows x 2 columns]

# %% [markdown]
# esem12_con115 -> esem12_con135
# sota3_115 -> sota3_135

# %%
submission_list = [esem8055, esem8040]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 13.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 13.5)


fname = 'esem8055, esem8040_con135.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'esem8055, esem8040_con135.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.756195
# 1        3501  0.260454
# 2        3502  0.206208
# 3        3503  0.267979
# 4        3504  0.439356
# ...       ...       ...
# 2477     5977  0.586924
# 2478     5978  0.404123
# 2479     5979  0.765160
# 2480     5980  0.415557
# 2481     5981  0.571957
#
# [2482 rows x 2 columns]

# %%
esem12_con135 = pd.read_csv('esem8055, esem8040_con135.csv', encoding='cp949')

# %%
submission_list = [Dnn7982, Dae7971, Cnn7974]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 13.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 13.5)


fname = 'Dnn7982, Dae7971, Cnn7974_135.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'Dnn7982, Dae7971, Cnn7974_135.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.669644
# 1        3501  0.296086
# 2        3502  0.390202
# 3        3503  0.533318
# 4        3504  0.575128
# ...       ...       ...
# 2477     5977  0.585582
# 2478     5978  0.443624
# 2479     5979  0.698831
# 2480     5980  0.399925
# 2481     5981  0.622729
#
# [2482 rows x 2 columns]

# %%
sota3_135 = pd.read_csv('Dnn7982, Dae7971, Cnn7974_135.csv', encoding='cp949')

# %% [markdown]
# 13.5찍은거로 조합해서 만들기

# %%
esem12_con135_sota3_135_weight = esem12_con135['gender'] * 0.6  + sota3_135['gender'] * 0.4

# %%
pred = esem12_con135_sota3_135_weight * 0.85 + ML123_con25_8055['gender'] * 0.15

# %%
esem12_con135_sota3_135_weight_ML123_con25_8055 = pd.DataFrame({'cust_id':range(3500, 5982), 'gender':pred})
esem12_con135_sota3_135_weight_ML123_con25_8055.to_csv('esem12_con135_sota3_135_weight_ML123_con25_8055.csv', encoding='cp949', index=False)
esem12_con135_sota3_135_weight_ML123_con25_8055
# Out:
#       cust_id    gender
# 0        3500  0.727298
# 1        3501  0.278812
# 2        3502  0.266546
# 3        3503  0.352978
# 4        3504  0.482645
# ...       ...       ...
# 2477     5977  0.570952
# 2478     5978  0.415856
# 2479     5979  0.742353
# 2480     5980  0.423296
# 2481     5981  0.591515
#
# [2482 rows x 2 columns]

# %% [markdown]
# esem12_con115 -> esem12_con135  -> esem12_con155
# sota3_115 -> sota3_135 -> sota3_155

# %%
submission_list = [esem8055, esem8040]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 15.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 15.5)


fname = 'esem8055, esem8040_con155.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'esem8055, esem8040_con155.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.757778
# 1        3501  0.260755
# 2        3502  0.206210
# 3        3503  0.268845
# 4        3504  0.441986
# ...       ...       ...
# 2477     5977  0.590180
# 2478     5978  0.406064
# 2479     5979  0.765927
# 2480     5980  0.415825
# 2481     5981  0.573569
#
# [2482 rows x 2 columns]

# %%
esem12_con155 = pd.read_csv('esem8055, esem8040_con155.csv', encoding='cp949')

# %%
submission_list = [Dnn7982, Dae7971, Cnn7974]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 15.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 15.5)


fname = 'Dnn7982, Dae7971, Cnn7974_155.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'Dnn7982, Dae7971, Cnn7974_155.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.673922
# 1        3501  0.298660
# 2        3502  0.394321
# 3        3503  0.538906
# 4        3504  0.579965
# ...       ...       ...
# 2477     5977  0.591138
# 2478     5978  0.447145
# 2479     5979  0.705131
# 2480     5980  0.400169
# 2481     5981  0.628059
#
# [2482 rows x 2 columns]

# %%
sota3_155 = pd.read_csv('Dnn7982, Dae7971, Cnn7974_155.csv', encoding='cp949')

# %% [markdown]
# 13.5찍은거로 조합해서 만들기

# %%
esem12_con155_sota3_155_weight = esem12_con155['gender'] * 0.6  + sota3_155['gender'] * 0.4

# %%
pred = esem12_con155_sota3_155_weight * 0.85 + ML123_con25_8055['gender'] * 0.15

# %%
esem12_con155_sota3_155_weight_ML123_con25_8055 = pd.DataFrame({'cust_id':range(3500, 5982), 'gender':pred})
esem12_con155_sota3_155_weight_ML123_con25_8055.to_csv('esem12_con155_sota3_155_weight_ML123_con25_8055.csv', encoding='cp949', index=False)
esem12_con155_sota3_155_weight_ML123_con25_8055
# Out:
#       cust_id    gender
# 0        3500  0.729560
# 1        3501  0.279840
# 2        3502  0.267947
# 3        3503  0.355320
# 4        3504  0.485631
# ...       ...       ...
# 2477     5977  0.574502
# 2478     5978  0.418043
# 2479     5979  0.744886
# 2480     5980  0.423516
# 2481     5981  0.594150
#
# [2482 rows x 2 columns]

# %% [markdown]
# ML123_con25_8055 -> ML123_con15

# %%
submission_list = [score7981, score7977]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 1.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 1.5)


fname = 'score7981, score7977_con_15.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'score7981, score7977_con_15.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.772495
# 1        3501  0.208582
# 2        3502  0.177947
# 3        3503  0.249852
# 4        3504  0.440134
# ...       ...       ...
# 2477     5977  0.532582
# 2478     5978  0.379664
# 2479     5979  0.762952
# 2480     5980  0.403650
# 2481     5981  0.536143
#
# [2482 rows x 2 columns]

# %%
ML23_con15 = pd.read_csv('score7981, score7977_con_15.csv', encoding='cp949')

# %%
submission_list = [ML23_con15, score7988]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 1.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 1.5)


fname = 'ML23_con15, score7988_con15.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'ML23_con15, score7988_con15.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.758100
# 1        3501  0.290252
# 2        3502  0.188207
# 3        3503  0.229335
# 4        3504  0.418776
# ...       ...       ...
# 2477     5977  0.478692
# 2478     5978  0.392409
# 2479     5979  0.763314
# 2480     5980  0.494811
# 2481     5981  0.585266
#
# [2482 rows x 2 columns]

# %%
ML123_con15 = pd.read_csv('ML23_con15, score7988_con15.csv', encoding='cp949')

# %% [markdown]
# p값 15.5랑 p값 1.5 섞기

# %%
esem12_con155_sota3_155_weight = esem12_con155['gender'] * 0.6  + sota3_155['gender'] * 0.4

# %%
pred = esem12_con155_sota3_155_weight * 0.85 + ML123_con15['gender'] * 0.15

# %%
esem12_con155_sota3_155_weight_ML123_con15 = pd.DataFrame({'cust_id':range(3500, 5982), 'gender':pred})
esem12_con155_sota3_155_weight_ML123_con15.to_csv('esem12_con155_sota3_155_weight_ML123_con15.csv', encoding='cp949', index=False)
esem12_con155_sota3_155_weight_ML123_con15
# Out:
#       cust_id    gender
# 0        3500  0.729315
# 1        3501  0.278067
# 2        3502  0.267467
# 3        3503  0.354739
# 4        3504  0.485417
# ...       ...       ...
# 2477     5977  0.573783
# 2478     5978  0.417983
# 2479     5979  0.744864
# 2480     5980  0.422350
# 2481     5981  0.593850
#
# [2482 rows x 2 columns]
