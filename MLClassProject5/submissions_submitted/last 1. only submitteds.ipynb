# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
from matplotlib import font_manager, rc
# %matplotlib inline

import platform
your_os = platform.system()
if your_os == 'Linux':
    rc('font', family='NanumGothic')
elif your_os == 'Windows':
    ttf = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=ttf).get_name()
    rc('font', family=font_name)
elif your_os == 'Darwin':
    rc('font', family='AppleGothic')
rc('axes', unicode_minus=False)

# %%
## Baseline: 0.80985

# 그룹과제 1등, 2등, 3등
score7981 = pd.read_csv('박혜지(7981).csv', encoding='cp949') # 14
score7977 = pd.read_csv('서진영(7977).csv', encoding='cp949') # 18
score7988 = pd.read_csv('홍재성(7988).csv', encoding='cp949') # 19

# 개인과제2 1등, 2등, 3등
w2v_7932 = pd.read_csv('김세홍(7932).csv', encoding='cp949')
w2v_7913 = pd.read_csv('권오현(7913).csv', encoding='cp949')
w2v_7883 = pd.read_csv('오주영(7883).csv', encoding='cp949')

# NN과제 1등, 2등, 3등
esem8055 = pd.read_csv('yj8055.csv', encoding='cp949')
esem8040 = pd.read_csv('hong8040.csv', encoding='cp949')
esem8031 = pd.read_csv('jin8031.csv', encoding='cp949')

# NN만점과제
Dnn7982 = pd.read_csv('Dnn7982.csv', encoding='cp949')
Dae7971 = pd.read_csv('DAE7971.csv', encoding='cp949')
Cnn7974 = pd.read_csv('Cnn17974.csv', encoding='cp949')

# 우리과제
ml_7880 = pd.read_csv('18logreg2(7880).csv', encoding='cp949')
ml_7868 = pd.read_csv('20logreg3(7868).csv', encoding='cp949')
ml_7830 = pd.read_csv('jun7830.csv', encoding='cp949')
w2v7789 = pd.read_csv('w2v송민규1.csv', encoding='cp949')
w2v7894 = pd.read_csv('w2v7894.csv', encoding='cp949')
Dnn_w2v_7800 = pd.read_csv('Dnn_w2v7800.csv', encoding='cp949')
Dae_us_7971 = pd.read_csv('DAE_us_7971.csv', encoding='cp949')


# 0.8이상 Ensemble submissions
score8091 = pd.read_csv('score7988 + w2v7932 + DAE7971.csv', encoding='cp949')
score8012 = pd.read_csv('score7977 + w2v_7913 + Dnn7982 + Cnn7974.csv', encoding='cp949')
score8062 = pd.read_csv('score7981, score7977, score7988, Dnn7982, Dae7971, Cnn7974.csv', encoding='cp949')
score8056 = pd.read_csv('esem8040, w2v_7913, Dnn7982, Dae7971, Cnn7974.csv', encoding='cp949')
score8043 = pd.read_csv('score7988, w2v_7883, Dae7971, ml_7880.csv', encoding='cp949')

# 민준 앙상블
score8070 = pd.read_csv('score8070.csv', encoding='cp949')
score8073 = pd.read_csv('score8073.csv', encoding='cp949')
score8074 = pd.read_csv('score8074.csv', encoding='cp949')
score8084 = pd.read_csv('score8084.csv', encoding='cp949')
score80780 = pd.read_csv('score80780.csv', encoding='cp949')
score80783 = pd.read_csv('score80783.csv', encoding='cp949')

# 민규 앙상블
score8085 = pd.read_csv('score8085.csv', encoding='cp949')
score8090 = pd.read_csv('score8090.csv', encoding='cp949')
score8095 = pd.read_csv('score8095.csv', encoding='cp949')

# %% [markdown]
# 제출한 것만 써보기

# %%
w2v8002 = pd.read_csv('w2v7894 w2v_7932 w2v_7913 w2v_7883.csv', encoding='cp949')
w2v8021 = pd.read_csv('w2v_7883 w2v_7932 w2v_7894.csv', encoding='cp949')
each8012 = pd.read_csv('score7977  w2v_7913  Dnn7982  Cnn7974.csv', encoding='cp949')
each8040 = pd.read_csv('1 2  w2v 3  dae.csv', encoding='cp949')
each8043 = pd.read_csv('score7988 w2v_7883 Dae7971 ml_7880.csv', encoding='cp949')
each8055 = pd.read_csv('h.csv', encoding='cp949')
jo8056 = pd.read_csv('a.csv', encoding='cp949')
ML2NN3_8062 = pd.read_csv('123   3.csv', encoding='cp949')
sotaEach8070 = pd.read_csv('f.csv', encoding='cp949')
baseEach8061 = pd.read_csv('i.csv', encoding='cp949')

# %%
# gender 이름 바꾸기전

submissions = [
    
# 그룹과제 1등, 2등, 3등
    score7981, score7977, score7988,
    
# 개인과제2 1등, 2등, 3등
    w2v_7932, w2v_7913, w2v_7883,

# NN과제 1등, 2등, 3등
    esem8055, esem8040, esem8031,

# NN만점과제
    Dnn7982, Dae7971, Cnn7974,

# 우리과제
    ml_7880, ml_7868, ml_7830, w2v7789, w2v7894, Dnn_w2v_7800, Dae_us_7971,
    
# 앙상블된 서브미션
    score8091, score8012, score8062, score8056, score8043,
    score8070, score8073, score8074, score8084, score80780, score80783,
    score8085, score8090, score8095
    
              ]
print(len(submissions))

names= [
    
# 그룹과제 1등, 2등, 3등
    'score7981', 'score7977', 'score7988',
    
# 개인과제2 1등, 2등, 3등
    'w2v_7932' ,'w2v_7913' ,'w2v_7883',

# NN과제 1등, 2등, 3등
    'esem8055', 'esem8040', 'esem8031',

# NN만점과제
    'Dnn7982', 'Dae7971', 'Cnn7974',

# 우리과제
    'ml_7880', 'ml_7868', 'ml_7830', 'w2v7789', 'w2v7894', 'Dnn_w2v_7800', 'Dae_us_7971',

# 앙상블된 서브미션
    'score8091', 'score8012', 'score8062', 'score8056', 'score8043',
    'score8070', 'score8073', 'score8074', 'score8084', 'score80780', 'score80783',
    'score8085', 'score8090', 'score8095'
    
       ]
# Out:
# 33

# %%
# gender 이름 바꾸기전

submissions = [
    w2v8002, w2v8021, each8012, each8040, each8043,
    each8055, jo8056, ML2NN3_8062, sotaEach8070, baseEach8061

# 앙상블된 서브미션
    
    
              ]
print(len(submissions))

names= [
    'w2v8002', "w2v8021", "each8012", 'each8040', 'each8043',
    'each8055', 'jo8056', 'ML2NN3_8062', 'sotaEach8070', 'baseEach8061'  

# 앙상블된 서브미션
    
    
       ]
# Out:
# 10

# %% [markdown]
# # After 8098 자유롭게 히트맵 뿌려서 조사

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
from matplotlib import font_manager, rc
# %matplotlib inline

import platform
your_os = platform.system()
if your_os == 'Linux':
    rc('font', family='NanumGothic')
elif your_os == 'Windows':
    ttf = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=ttf).get_name()
    rc('font', family=font_name)
elif your_os == 'Darwin':
    rc('font', family='AppleGothic')
rc('axes', unicode_minus=False)

# %%
## Baseline: 0.80985

# 그룹과제 1등, 2등, 3등
score7981 = pd.read_csv('박혜지(7981).csv', encoding='cp949') # 14
score7977 = pd.read_csv('서진영(7977).csv', encoding='cp949') # 18
score7988 = pd.read_csv('홍재성(7988).csv', encoding='cp949') # 19

# 개인과제2 1등, 2등, 3등
w2v_7932 = pd.read_csv('김세홍(7932).csv', encoding='cp949')
w2v_7913 = pd.read_csv('권오현(7913).csv', encoding='cp949')
w2v_7883 = pd.read_csv('오주영(7883).csv', encoding='cp949')

# NN과제 1등, 2등, 3등
esem8055 = pd.read_csv('yj8055.csv', encoding='cp949')
esem8040 = pd.read_csv('hong8040.csv', encoding='cp949')
esem8031 = pd.read_csv('jin8031.csv', encoding='cp949')

# NN만점과제
Dnn7982 = pd.read_csv('Dnn7982.csv', encoding='cp949')
Dae7971 = pd.read_csv('DAE7971.csv', encoding='cp949')
Cnn7974 = pd.read_csv('Cnn17974.csv', encoding='cp949')

# 우리과제
ml_7880 = pd.read_csv('18logreg2(7880).csv', encoding='cp949')
#ml_7868 = pd.read_csv('20logreg3(7868).csv', encoding='cp949')
#ml_7830 = pd.read_csv('jun7830.csv', encoding='cp949')
#w2v7789 = pd.read_csv('w2v송민규1.csv', encoding='cp949')
w2v8021 = pd.read_csv('w2v_7883, w2v_7932, w2v_7894.csv', encoding='cp949')
w2v7894 = pd.read_csv('w2v7894.csv', encoding='cp949')
#Dnn_w2v_7800 = pd.read_csv('Dnn_w2v7800.csv', encoding='cp949')
Dae_us_7971 = pd.read_csv('DAE_us_7971.csv', encoding='cp949')

# # 0.8이상 Ensemble submissions
# score8091 = pd.read_csv('score7988 + w2v7932 + DAE7971.csv', encoding='cp949')
# score8012 = pd.read_csv('score7977 + w2v_7913 + Dnn7982 + Cnn7974.csv', encoding='cp949')
# score8062 = pd.read_csv('score7981, score7977, score7988, Dnn7982, Dae7971, Cnn7974.csv', encoding='cp949')
# score8056 = pd.read_csv('esem8040, w2v_7913, Dnn7982, Dae7971, Cnn7974.csv', encoding='cp949')
# score8043 = pd.read_csv('score7988, w2v_7883, Dae7971, ml_7880.csv', encoding='cp949')

# # 민준 앙상블
# score8070 = pd.read_csv('score8070.csv', encoding='cp949')
# score8073 = pd.read_csv('score8073.csv', encoding='cp949')
# score8074 = pd.read_csv('score8074.csv', encoding='cp949')
# score8084 = pd.read_csv('score8084.csv', encoding='cp949')
# score80780 = pd.read_csv('score80780.csv', encoding='cp949')
# score80783 = pd.read_csv('score80783.csv', encoding='cp949')

# # 민규 앙상블
# score8085 = pd.read_csv('score8085.csv', encoding='cp949')
# score8090 = pd.read_csv('score8090.csv', encoding='cp949')
# score8095 = pd.read_csv('score8095.csv', encoding='cp949')

# simliar score to baseline (0.80985)
score8098 = pd.read_csv('score8095, w2v_7932, Dae7971.csv', encoding='cp949')
score8097 = pd.read_csv('cnn7974, dae7971, dnn7982, score8040, score8031, score8055, score8021, dae7971.csv', encoding='cp949')

# %%
# gender 이름 바꾸기전

submissions = [
    
# ML - manual
    score7981, score7977, score7988,ml_7880,
    
# ML - W2V
    w2v_7932, w2v_7913, w2v_7883, w2v8021, w2v7894,

# NN - group
    esem8055, esem8040, esem8031,

# NN - indiviual
    Dnn7982, Dae7971, Cnn7974, Dae_us_7971,

# ALL - ensemble
    
    score8098, score8097
    
              ]
print(len(submissions))

names= [
    
# ML - manual
    'score7981', 'score7977', 'score7988', 'ml_7880',
    
# ML - W2V
    'w2v_7932', 'w2v_7913', 'w2v_7883', 'w2v8021', 'w2v7894',

# NN - group
    'esem8055', 'esem8040', 'esem8031',

# NN - indiviual
    'Dnn7982', 'Dae7971', 'Cnn7974', 'Dae_us_7971',

# ALL - ensemble
    
    'score8098', 'score8097'
    
       ]
# Out:
# 18

# %%
# 각 submission별 gender 칼럼명 변경

for i in range(len(submissions)):
    

    submissions[i].rename(columns={'gender':f'{names[i]}'}, inplace=True)

# %%
        n=1

        for submission in submissions:

            print(n); n +=1
    
    display(submission)
# Out:
# 1
#       cust_id   w2v8002
# 0        3500  0.684365
# 1        3501  0.229008
# 2        3502  0.236113
# 3        3503  0.285536
# 4        3504  0.389809
# ...       ...       ...
# 2477     5977  0.469958
# 2478     5978  0.295198
# 2479     5979  0.689669
# 2480     5980  0.424806
# 2481     5981  0.629425
#
# [2482 rows x 2 columns]
# 2
#       cust_id   w2v8021
# 0        3500  0.702567
# 1        3501  0.226553
# 2        3502  0.247087
# 3        3503  0.279563
# 4        3504  0.399995
# ...       ...       ...
# 2477     5977  0.410180
# 2478     5978  0.307057
# 2479     5979  0.731491
# 2480     5980  0.426476
# 2481     5981  0.648234
#
# [2482 rows x 2 columns]
# 3
#       cust_id  each8012
# 0        3500  0.712374
# 1        3501  0.255319
# 2        3502  0.294628
# 3        3503  0.420022
# 4        3504  0.490066
# ...       ...       ...
# 2477     5977  0.569753
# 2478     5978  0.335268
# 2479     5979  0.656253
# 2480     5980  0.403067
# 2481     5981  0.580898
#
# [2482 rows x 2 columns]
# 4
#       cust_id  each8040
# 0        3500  0.655997
# 1        3501  0.225304
# 2        3502  0.178309
# 3        3503  0.291762
# 4        3504  0.451252
# ...       ...       ...
# 2477     5977  0.449447
# 2478     5978  0.395782
# 2479     5979  0.638335
# 2480     5980  0.381739
# 2481     5981  0.556592
#
# [2482 rows x 2 columns]
# 5
#       cust_id  each8043
# 0        3500  0.707790
# 1        3501  0.268717
# 2        3502  0.157974
# 3        3503  0.250355
# 4        3504  0.403187
# ...       ...       ...
# 2477     5977  0.436615
# 2478     5978  0.377861
# 2479     5979  0.672032
# 2480     5980  0.459341
# 2481     5981  0.574576
#
# [2482 rows x 2 columns]
# 6
#       cust_id  each8055
# 0        3500  0.702480
# 1        3501  0.260259
# 2        3502  0.290375
# 3        3503  0.398858
# 4        3504  0.468616
# ...       ...       ...
# 2477     5977  0.520316
# 2478     5978  0.358211
# 2479     5979  0.716622
# 2480     5980  0.402918
# 2481     5981  0.605101
#
# [2482 rows x 2 columns]
# 7
#       cust_id    jo8056
# 0        3500  0.690250
# 1        3501  0.260451
# 2        3502  0.275069
# 3        3503  0.392433
# 4        3504  0.486550
# ...       ...       ...
# 2477     5977  0.534662
# 2478     5978  0.396396
# 2479     5979  0.697883
# 2480     5980  0.401113
# 2481     5981  0.569541
#
# [2482 rows x 2 columns]
# 8
#       cust_id  ML2NN3_8062
# 0        3500     0.711247
# 1        3501     0.282313
# 2        3502     0.271366
# 3        3503     0.384524
# 4        3504     0.491016
# ...       ...          ...
# 2477     5977     0.519600
# 2478     5978     0.397063
# 2479     5979     0.709503
# 2480     5980     0.444560
# 2481     5981     0.576698
#
# [2482 rows x 2 columns]
# 9
#       cust_id  sotaEach8070
# 0        3500      0.704988
# 1        3501      0.294756
# 2        3502      0.298231
# 3        3503      0.406861
# 4        3504      0.485772
# ...       ...           ...
# 2477     5977      0.494786
# 2478     5978      0.392916
# 2479     5979      0.734295
# 2480     5980      0.447746
# 2481     5981      0.613793
#
# [2482 rows x 2 columns]
# 10
#       cust_id  baseEach8061
# 0        3500      0.746888
# 1        3501      0.287716
# 2        3502      0.255622
# 3        3503      0.300341
# 4        3504      0.393755
# ...       ...           ...
# 2477     5977      0.455545
# 2478     5978      0.376827
# 2479     5979      0.780333
# 2480     5980      0.444347
# 2481     5981      0.625318
#
# [2482 rows x 2 columns]

# %%
# 데이터 합치기

data = pd.DataFrame({'cust_id': range(3500,5982)})
for sub in submissions :
    data = pd.merge(data, sub, how='left', on='cust_id')
display(data)
data.info()
# Out:
#       cust_id   w2v8002   w2v8021  each8012  each8040  each8043  each8055  \
# 0        3500  0.684365  0.702567  0.712374  0.655997  0.707790  0.702480
# 1        3501  0.229008  0.226553  0.255319  0.225304  0.268717  0.260259
# 2        3502  0.236113  0.247087  0.294628  0.178309  0.157974  0.290375
# 3        3503  0.285536  0.279563  0.420022  0.291762  0.250355  0.398858
# 4        3504  0.389809  0.399995  0.490066  0.451252  0.403187  0.468616
# ...       ...       ...       ...       ...       ...       ...       ...
# 2477     5977  0.469958  0.410180  0.569753  0.449447  0.436615  0.520316
# 2478     5978  0.295198  0.307057  0.335268  0.395782  0.377861  0.358211
# 2479     5979  0.689669  0.731491  0.656253  0.638335  0.672032  0.716622
# 2480     5980  0.424806  0.426476  0.403067  0.381739  0.459341  0.402918
# 2481     5981  0.629425  0.648234  0.580898  0.556592  0.574576  0.605101
#
#         jo8056  ML2NN3_8062  sotaEach8070  baseEach8061
# 0     0.690250     0.711247      0.704988      0.746888
# 1     0.260451     0.282313      0.294756      0.287716
# 2     0.275069     0.271366      0.298231      0.255622
# 3     0.392433     0.384524      0.406861      0.300341
# 4     0.486550     0.491016      0.485772      0.393755
# ...        ...          ...           ...           ...
# 2477  0.534662     0.519600      0.494786      0.455545
# 2478  0.396396     0.397063      0.392916      0.376827
# 2479  0.697883     0.709503      0.734295      0.780333
# 2480  0.401113     0.444560      0.447746      0.444347
# 2481  0.569541     0.576698      0.613793      0.625318
#
# [2482 rows x 11 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2482 entries, 0 to 2481
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cust_id       2482 non-null   int64
#  1   w2v8002       2482 non-null   float64
#  2   w2v8021       2482 non-null   float64
#  3   each8012      2482 non-null   float64
#  4   each8040      2482 non-null   float64
#  5   each8043      2482 non-null   float64
#  6   each8055      2482 non-null   float64
#  7   jo8056        2482 non-null   float64
#  8   ML2NN3_8062   2482 non-null   float64
#  9   sotaEach8070  2482 non-null   float64
#  10  baseEach8061  2482 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 232.7 KB

# %%
data = data.drop('cust_id', axis=1); data
# Out:
#        w2v8002   w2v8021  each8012  each8040  each8043  each8055    jo8056  \
# 0     0.684365  0.702567  0.712374  0.655997  0.707790  0.702480  0.690250
# 1     0.229008  0.226553  0.255319  0.225304  0.268717  0.260259  0.260451
# 2     0.236113  0.247087  0.294628  0.178309  0.157974  0.290375  0.275069
# 3     0.285536  0.279563  0.420022  0.291762  0.250355  0.398858  0.392433
# 4     0.389809  0.399995  0.490066  0.451252  0.403187  0.468616  0.486550
# ...        ...       ...       ...       ...       ...       ...       ...
# 2477  0.469958  0.410180  0.569753  0.449447  0.436615  0.520316  0.534662
# 2478  0.295198  0.307057  0.335268  0.395782  0.377861  0.358211  0.396396
# 2479  0.689669  0.731491  0.656253  0.638335  0.672032  0.716622  0.697883
# 2480  0.424806  0.426476  0.403067  0.381739  0.459341  0.402918  0.401113
# 2481  0.629425  0.648234  0.580898  0.556592  0.574576  0.605101  0.569541
#
#       ML2NN3_8062  sotaEach8070  baseEach8061
# 0        0.711247      0.704988      0.746888
# 1        0.282313      0.294756      0.287716
# 2        0.271366      0.298231      0.255622
# 3        0.384524      0.406861      0.300341
# 4        0.491016      0.485772      0.393755
# ...           ...           ...           ...
# 2477     0.519600      0.494786      0.455545
# 2478     0.397063      0.392916      0.376827
# 2479     0.709503      0.734295      0.780333
# 2480     0.444560      0.447746      0.444347
# 2481     0.576698      0.613793      0.625318
#
# [2482 rows x 10 columns]

# %%
# 서브미션간 상관관계 히트맵

plt.figure(figsize=(20,11))
sns.heatmap(data.corr(), annot=True, cmap='RdYlBu_r', linewidths=0.2)
plt.show()

# %%
submission_list = [Dnn7982, score7988, w2v8021, Dae7971, Cnn7974]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 3.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 3.5)


fname = 'Dnn7982, score7988, w2v8021, Dae7971, Cnn7974.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'Dnn7982, score7988, w2v8021, Dae7971, Cnn7974.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.677474
# 1        3501  0.291569
# 2        3502  0.287883
# 3        3503  0.401600
# 4        3504  0.493505
# ...       ...       ...
# 2477     5977  0.493594
# 2478     5978  0.389728
# 2479     5979  0.689649
# 2480     5980  0.454994
# 2481     5981  0.606231
#
# [2482 rows x 2 columns]

# %%
submission_list = [score8098, score7988, Dnn7982, Cnn7974]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 3.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 3.5)


fname = 'score8098, score7988, Dnn7982, Cnn7974.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'score8098, score7988, Dnn7982, Cnn7974.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.699734
# 1        3501  0.304713
# 2        3502  0.307612
# 3        3503  0.426536
# 4        3504  0.502931
# ...       ...       ...
# 2477     5977  0.510498
# 2478     5978  0.382637
# 2479     5979  0.715366
# 2480     5980  0.461897
# 2481     5981  0.612800
#
# [2482 rows x 2 columns]

# %%
submission_list = [w2v8021, score7977, Dae7971]

sum_pred = np.zeros(2482)
for sub in submission_list:
    
    sum_pred += sub.iloc[:,1] ** 3.5
    
pred = (sum_pred / len(submission_list)) ** (1 / 3.5)


fname = 'w2v8021, score7977, Dae7971.csv'
IDtest = range(3500, 5982)
submissions = pd.concat([pd.Series(IDtest, name="cust_id"), pd.Series(pred, name="gender")] ,axis=1)
submissions.to_csv(fname, index=False)
print("'{}' is ready to submit." .format(fname))

pd.read_csv(fname, encoding='cp949')
# Out:
# 'w2v8021, score7977, Dae7971.csv' is ready to submit.
#       cust_id    gender
# 0        3500  0.724514
# 1        3501  0.214630
# 2        3502  0.193312
# 3        3503  0.270311
# 4        3504  0.434223
# ...       ...       ...
# 2477     5977  0.505017
# 2478     5978  0.398661
# 2479     5979  0.696577
# 2480     5980  0.399195
# 2481     5981  0.568750
#
# [2482 rows x 2 columns]

# %%
score8098
# Out:
#       cust_id  score8098
# 0        3500   0.708202
# 1        3501   0.251981
# 2        3502   0.263438
# 3        3503   0.348421
# 4        3504   0.446489
# ...       ...        ...
# 2477     5977   0.483822
# 2478     5978   0.413223
# 2479     5979   0.753226
# 2480     5980   0.388797
# 2481     5981   0.594853
#
# [2482 rows x 2 columns]
